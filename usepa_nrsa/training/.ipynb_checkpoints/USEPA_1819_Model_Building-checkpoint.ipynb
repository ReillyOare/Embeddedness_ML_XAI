# %% [markdown]
# # USEPA Embeddedness 2018-2019 Model Building
# The purpose of this Jupyter Notebook is to test a few standard models on the EPA 2018-2019 NRSA datasets to predict reach-level gravel streambed embeddedness. We test out a random forest regressor, a gradient boosting regressor, an XGBoost regressor, an adaptive boosting regressor, and an FNN. Prior analysis revealed that boosting models had the most success both with the original Virginia dataset and with the EPA dataset as a whole.
#
# E. Reilly Oare.

# %%
# Read in libs
import os 
import warnings 
import pylab 
import json
import pandas as pd 
import numpy as np
import openpyxl 
import joblib
import matplotlib.pyplot as plt
import matplotlib as mpl 
import seaborn as sns
from scipy.interpolate import griddata
from sklearn.preprocessing import (
    RobustScaler,
    OneHotEncoder
)
from sklearn.model_selection import (
    train_test_split,
    KFold,
    cross_val_score 
)
from sklearn.metrics import (
    r2_score, 
    mean_squared_error, 
    mean_absolute_error
)
from sklearn.ensemble import (
    RandomForestRegressor, 
    GradientBoostingRegressor 
)
import xgboost as xgb
from xgboost import XGBRegressor
import tensorflow as tf 
from tensorflow.keras import datasets, layers, models
import keras
from keras.models import Sequential, Model 
from keras.layers import (
    Dense, 
    BatchNormalization, 
    Dropout, 
    Input, 
    LeakyReLU, 
    Activation, 
    Add
)
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam 
from keras import regularizers
from tensorflow.keras.regularizers import l2
import optuna

# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 1. Import Dataset

# %%
# Define base directory
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "../.."))

# %%
# Read in file
epa_path = os.path.join(BASE_DIR, "data", "model_ready", "usepa_1819_mdl.xlsx")
epa_1819 = pd.read_excel(epa_path).drop(columns = ['Unnamed: 0']).rename(columns = {
    'CTI Wetness Index (QT)':'CTI (QT)',
    '% Evergreen Forest (CBRT)':'% Evergreen Forest (cbrt)',
    '% Crop Land (CBRT)':'% Crop Land (cbrt)',
    '% Deciduous Forest (CBRT)':'% Deciduous Forest (cbrt)',
    '% Hay (CBRT)':'% Hay (cbrt)'
})

# %%
# Display dataframe
epa_1819
# Out:
#             Site ID  Unique ID   Latitude   Longitude Collection Date  \
# 0    NRS18_AR_10190    2012859  34.280395  -94.448356      2018-07-11
# 1    NRS18_MI_10050    2013955  44.183918  -86.171185      2019-07-01
# 2    NRS18_NM_10645    2013608  36.597293 -106.063509      2019-04-25
# 3    NRS18_NE_10011    2013596  40.357431  -98.130438      2018-09-27
# 4    NRS18_AZ_10843    2013644  34.226934 -111.456414      2019-05-10
# ..              ...        ...        ...         ...             ...
# 957  NRS18_MT_11470    2014194  46.791930 -107.837106      2019-07-24
# 958  NRS18_WY_11151    2013486  44.575647 -109.105182      2018-09-12
# 959  NRS18_WY_10029    2013358  44.074227 -105.254597      2018-08-27
# 960  NRS18_MT_10009    2014323  46.585589 -111.265709      2019-08-06
# 961  NRS18_IA_RF002    2014626  43.377180  -91.397360      2019-09-11
#
#      Streambed Embeddedness (%)  Bankfull Shear Velocity (m/s) (QT)  \
# 0                     28.818182                            0.251731
# 1                     61.250000                           -0.580000
# 2                     52.545455                            1.470157
# 3                     92.727273                           -0.688473
# 4                     48.200000                            0.592389
# ..                          ...                                 ...
# 957                   46.909091                           -0.583089
# 958                   64.727273                            0.361130
# 959                   98.181818                           -1.145937
# 960                   17.636364                            1.203124
# 961                   68.909091                            0.358348
#
#      Soil Bulk Density (QT)  Avg Watershed Elev (QT)  \
# 0                  1.219420                -0.347244
# 1                  0.963957                -0.662260
# 2                 -0.460495                 1.635343
# 3                 -0.259817                 0.846090
# 4                  0.111083                 0.777193
# ..                      ...                      ...
# 957                0.182285                 0.633304
# 958               -1.288101                 0.887872
# 959               -1.390385                 0.708446
# 960               -0.024782                 1.203124
# 961               -0.448925                -0.475044
#
#      Hydraulic Conductivity (QT)  ...  Impervious Surface (YJ)  \
# 0                      -0.460495  ...                 0.347176
# 1                       2.562044  ...                 0.060981
# 2                       0.483822  ...                -0.850664
# 3                       1.363463  ...                 0.667423
# 4                       0.155825  ...                 0.835865
# ..                           ...  ...                      ...
# 957                     1.015026  ...                -0.883857
# 958                     0.939343  ...                -0.631708
# 959                     0.540329  ...                -0.894331
# 960                    -1.863194  ...                -1.409289
# 961                    -0.011738  ...                 0.412684
#
#      Annual Runoff (QT)  CTI (QT)  Atlantic Plain Division  \
# 0              0.864894 -0.414566                    False
# 1              0.394749  1.363463                    False
# 2             -0.763158 -0.668770                    False
# 3             -0.784269  0.592389                    False
# 4             -0.698425 -0.705098                    False
# ..                  ...       ...                      ...
# 957           -0.976485  0.243663                    False
# 958           -0.394749 -0.411725                    False
# 959           -2.394362  0.475044                    False
# 960           -0.706771 -0.773670                    False
# 961           -0.056109 -0.576917                    False
#
#      Interior Highlands Division  Interior Plains Division  \
# 0                           True                     False
# 1                          False                      True
# 2                          False                     False
# 3                          False                      True
# 4                          False                     False
# ..                           ...                       ...
# 957                        False                      True
# 958                        False                     False
# 959                        False                      True
# 960                        False                     False
# 961                        False                      True
#
#      Intermontane Plateaus Division  Laurentian Upland Division  \
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                              True                       False
# ..                              ...                         ...
# 957                           False                       False
# 958                           False                       False
# 959                           False                       False
# 960                           False                       False
# 961                           False                       False
#
#      Pacific Mountain Division  Rocky Mountain Division
# 0                        False                    False
# 1                        False                    False
# 2                        False                     True
# 3                        False                    False
# 4                        False                    False
# ..                         ...                      ...
# 957                      False                    False
# 958                      False                     True
# 959                      False                    False
# 960                      False                     True
# 961                      False                    False
#
# [962 rows x 24 columns]

# %% [markdown]
# ## Step 2. Dataset Preparation

# %% [markdown]
# ### Step 2a. Train Test Split
# We will use an 80/20 train/test split since that has worked best with model building in the past for these datasets. However, this was evaluated using trial-and-error. The main issue was not having enough training to reduce the chance of underfitting.

# %%
# Define numerical columns
num_cols = ['Latitude', 'Longitude',
           'Bankfull Shear Velocity (m/s) (QT)',
           'Soil Bulk Density (QT)', 'Avg Watershed Elev (QT)',
           'Hydraulic Conductivity (QT)', '% Evergreen Forest (cbrt)',
           '% Crop Land (cbrt)', '% Deciduous Forest (cbrt)', '% Hay (cbrt)',
           'Impervious Surface (YJ)', 'Annual Runoff (QT)',
           'CTI (QT)']

# Define categorical columns
geo_cols = ['Atlantic Plain Division',
            'Interior Highlands Division',
            'Interior Plains Division',
            'Intermontane Plateaus Division',
            'Laurentian Upland Division',
            'Pacific Mountain Division',
            'Rocky Mountain Division']

# %% [markdown]
# #### Different Features Available
# Above, we have identified the features that we think will work best during model building. However, through trial-and-error, we found a few instances that were *not* successful. In the 'results' folder, there is a 'log' txt file that keeps track of CV metrics for various combinations of model building.

# %%
# Split into x and y dataframes
x = epa_1819[num_cols + geo_cols]
y = epa_1819[['Streambed Embeddedness (%)']]

# Check x dataframe
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Latitude                            962 non-null    float64
#  1   Longitude                           962 non-null    float64
#  2   Bankfull Shear Velocity (m/s) (QT)  962 non-null    float64
#  3   Soil Bulk Density (QT)              962 non-null    float64
#  4   Avg Watershed Elev (QT)             962 non-null    float64
#  5   Hydraulic Conductivity (QT)         962 non-null    float64
#  6   % Evergreen Forest (cbrt)           962 non-null    float64
#  7   % Crop Land (cbrt)                  962 non-null    float64
#  8   % Deciduous Forest (cbrt)           962 non-null    float64
#  9   % Hay (cbrt)                        962 non-null    float64
#  10  Impervious Surface (YJ)             962 non-null    float64
#  11  Annual Runoff (QT)                  962 non-null    float64
#  12  CTI (QT)                            962 non-null    float64
#  13  Atlantic Plain Division             962 non-null    bool
#  14  Interior Highlands Division         962 non-null    bool
#  15  Interior Plains Division            962 non-null    bool
#  16  Intermontane Plateaus Division      962 non-null    bool
#  17  Laurentian Upland Division          962 non-null    bool
#  18  Pacific Mountain Division           962 non-null    bool
#  19  Rocky Mountain Division             962 non-null    bool
# dtypes: bool(7), float64(13)
# memory usage: 104.4 KB

# %%
# Check y dataframe
y
# Out:
#      Streambed Embeddedness (%)
# 0                     28.818182
# 1                     61.250000
# 2                     52.545455
# 3                     92.727273
# 4                     48.200000
# ..                          ...
# 957                   46.909091
# 958                   64.727273
# 959                   98.181818
# 960                   17.636364
# 961                   68.909091
#
# [962 rows x 1 columns]

# %%
# Split x_scld and y using Sklearn
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    random_state = 42,
                                                    test_size = 0.2)

# %%
# Check test shape
x_test
# Out:
#       Latitude   Longitude  Bankfull Shear Velocity (m/s) (QT)  \
# 344  32.912152 -110.477373                            0.583089
# 381  47.573646 -123.583234                            1.121143
# 351  41.988899 -114.995950                            0.240976
# 778  43.919047  -71.537224                            2.154289
# 277  42.756742  -72.463348                            0.972292
# ..         ...         ...                                 ...
# 551  40.501014 -100.319590                           -1.121143
# 33   43.840997 -122.820758                            1.397275
# 31   35.749309  -97.134335                           -0.555483
# 716  42.968172  -84.051734                           -0.501492
# 941  38.625745  -86.426701                           -1.343902
#
#      Soil Bulk Density (QT)  Avg Watershed Elev (QT)  \
# 344               -0.325164                 0.665512
# 381               -3.078398                 0.498536
# 351               -1.050596                 1.106592
# 778               -1.356885                 0.222221
# 277               -0.247695                -0.927247
# ..                      ...                      ...
# 551                0.659016                 0.406053
# 33                -1.655541                 0.179634
# 31                 1.749962                -0.494111
# 716               -0.286894                -0.672036
# 941                0.035220                -0.903454
#
#      Hydraulic Conductivity (QT)  % Evergreen Forest (cbrt)  \
# 344                     0.963957                   2.546540
# 381                    -1.037103                   4.348194
# 351                     0.053497                   0.776528
# 778                    -2.734712                   4.025665
# 277                    -0.951578                   2.856397
# ..                           ...                        ...
# 551                     0.633304                   0.627794
# 33                     -1.665899                   4.386503
# 31                     -0.528295                   0.665278
# 716                     1.370100                   0.756430
# 941                    -1.509726                   0.184702
#
#      % Crop Land (cbrt)  % Deciduous Forest (cbrt)  % Hay (cbrt)  \
# 344            0.156694                   0.000000      0.000000
# 381            0.000000                   0.555682      0.000000
# 351            0.000000                   0.820455      0.000000
# 778            0.000000                   1.563924      0.000000
# 277            0.000000                   2.805379      1.124062
# ..                  ...                        ...           ...
# 551            2.933652                   0.558860      0.833537
# 33             0.000000                   0.000000      0.000000
# 31             1.475567                   3.427753      1.428343
# 716            2.997743                   2.597730      2.332626
# 941            4.063130                   2.199227      2.507021
#
#      Impervious Surface (YJ)  Annual Runoff (QT)  CTI (QT)  \
# 344                -1.035421           -1.208521 -1.015026
# 381                -1.402606            3.078398 -2.350852
# 351                -0.852343           -1.140922 -0.206208
# 778                -1.409289            1.676438 -1.161158
# 277                -0.574726            0.903454 -0.711803
# ..                       ...                 ...       ...
# 551                -0.621933           -1.615791  0.074407
# 33                 -0.801285            2.016914 -0.812974
# 31                 -0.430677           -0.363916  0.146591
# 716                 1.643299           -0.147910  1.187142
# 941                 0.346725            0.389116  0.919258
#
#      Atlantic Plain Division  Interior Highlands Division  \
# 344                    False                        False
# 381                    False                        False
# 351                    False                        False
# 778                    False                        False
# 277                    False                        False
# ..                       ...                          ...
# 551                    False                        False
# 33                     False                        False
# 31                     False                        False
# 716                    False                        False
# 941                    False                        False
#
#      Interior Plains Division  Intermontane Plateaus Division  \
# 344                     False                            True
# 381                     False                           False
# 351                     False                            True
# 778                     False                           False
# 277                     False                           False
# ..                        ...                             ...
# 551                      True                           False
# 33                      False                           False
# 31                       True                           False
# 716                      True                           False
# 941                      True                           False
#
#      Laurentian Upland Division  Pacific Mountain Division  \
# 344                       False                      False
# 381                       False                       True
# 351                       False                      False
# 778                       False                      False
# 277                       False                      False
# ..                          ...                        ...
# 551                       False                      False
# 33                        False                       True
# 31                        False                      False
# 716                       False                      False
# 941                       False                      False
#
#      Rocky Mountain Division
# 344                    False
# 381                    False
# 351                    False
# 778                    False
# 277                    False
# ..                       ...
# 551                    False
# 33                     False
# 31                     False
# 716                    False
# 941                    False
#
# [193 rows x 20 columns]

# %%
# Check training shape
y_train
# Out:
#      Streambed Embeddedness (%)
# 468                   29.090909
# 857                   78.545455
# 549                   48.363636
# 280                   15.454545
# 109                   18.363636
# ..                          ...
# 106                   64.545455
# 270                   68.181818
# 860                   65.377358
# 435                   87.927273
# 102                   71.818182
#
# [769 rows x 1 columns]

# %% [markdown]
# ### Step 2b. Feature Scaling
# Scaling will be applied to numerical columns only (not one-hot encoded columns). The **RobustScaler** was used based on trial-and-error. Technically, you don't need to scale for tree-based models, but we will use it anyways to ensure consistency.

# %%
# Initialize scaler and fit on training numerical data
scaler = RobustScaler()
x_train_num = pd.DataFrame(scaler.fit_transform(x_train[num_cols]), 
                           columns=num_cols, 
                           index=x_train.index).astype(float)
x_test_num = pd.DataFrame(scaler.transform(x_test[num_cols]), 
                          columns=num_cols, 
                          index=x_test.index).astype(float)
x_full_num = pd.DataFrame(scaler.transform(x[num_cols]), 
                          columns=num_cols, 
                          index=x.index).astype(float)

# Ensure geo_cols remain boolean
x_train_physio = x_train[geo_cols].astype(bool)
x_test_physio = x_test[geo_cols].astype(bool)
x_full_physio = x[geo_cols].astype(bool)

# Concatenate all columns
x_train_scld = pd.concat([x_train_num, x_train_physio], axis = 1)
x_test_scld = pd.concat([x_test_num, x_test_physio], axis = 1)
x_scld = pd.concat([x_full_num, x_full_physio], axis = 1)

# Validate dtypes
print(f"\n###Training Data Types:###\n {x_train_scld.dtypes}")
print(f"\n###Testing Data Types:###\n {x_test_scld.dtypes}")
print(f"\n###Full Dataset Data Types:###\n {x_scld.dtypes}")
# Out:
# ###Training Data Types:###
#  Latitude                              float64
# Longitude                             float64
# Bankfull Shear Velocity (m/s) (QT)    float64
# Soil Bulk Density (QT)                float64
# Avg Watershed Elev (QT)               float64
# Hydraulic Conductivity (QT)           float64
# % Evergreen Forest (cbrt)             float64
# % Crop Land (cbrt)                    float64
# % Deciduous Forest (cbrt)             float64
# % Hay (cbrt)                          float64
# Impervious Surface (YJ)               float64
# Annual Runoff (QT)                    float64
# CTI (QT)                              float64
# Atlantic Plain Division                  bool
# Interior Highlands Division              bool
# Interior Plains Division                 bool
# Intermontane Plateaus Division           bool
# Laurentian Upland Division               bool
# Pacific Mountain Division                bool
# Rocky Mountain Division                  bool
# dtype: object
#
# ###Testing Data Types:###
#  Latitude                              float64
# Longitude                             float64
# Bankfull Shear Velocity (m/s) (QT)    float64
# Soil Bulk Density (QT)                float64
# Avg Watershed Elev (QT)               float64
# Hydraulic Conductivity (QT)           float64
# % Evergreen Forest (cbrt)             float64
# % Crop Land (cbrt)                    float64
# % Deciduous Forest (cbrt)             float64
# % Hay (cbrt)                          float64
# Impervious Surface (YJ)               float64
# Annual Runoff (QT)                    float64
# CTI (QT)                              float64
# Atlantic Plain Division                  bool
# Interior Highlands Division              bool
# Interior Plains Division                 bool
# Intermontane Plateaus Division           bool
# Laurentian Upland Division               bool
# Pacific Mountain Division                bool
# Rocky Mountain Division                  bool
# dtype: object
#
# ###Full Dataset Data Types:###
#  Latitude                              float64
# Longitude                             float64
# Bankfull Shear Velocity (m/s) (QT)    float64
# Soil Bulk Density (QT)                float64
# Avg Watershed Elev (QT)               float64
# Hydraulic Conductivity (QT)           float64
# % Evergreen Forest (cbrt)             float64
# % Crop Land (cbrt)                    float64
# % Deciduous Forest (cbrt)             float64
# % Hay (cbrt)                          float64
# Impervious Surface (YJ)               float64
# Annual Runoff (QT)                    float64
# CTI (QT)                              float64
# Atlantic Plain Division                  bool
# Interior Highlands Division              bool
# Interior Plains Division                 bool
# Intermontane Plateaus Division           bool
# Laurentian Upland Division               bool
# Pacific Mountain Division                bool
# Rocky Mountain Division                  bool
# dtype: object

# %% [markdown]
# ## Step 3. Model Building
# We will be testing multiple models to identify the most successful model given the dataset. The main cross-validation metrics for model selection will include MAE, RMSE, and NSE. We will test:
# 1. Random Forest Regression
# 2. Gradient Boosting Regression
# 3. XGBoost
# 4. FNN

# %% [markdown]
# ### Step 3a. Define CV Metrics

# %%
# Create global metric dataframe
metric_df = pd.DataFrame(columns=['Model', 'CV RMSE', 'CV MAE', 'CV R2', 'CV NSE'])

# Establish a coordinate df
coords_df = epa_1819.loc[x_scld.index, ['Latitude', 'Longitude']]

# Define function used for metric calculations and plotting
def kfold_model_metrics(model_name, model_builder, X, Y, coords=None, cv=5, save_path_figures=None, save_path_csv=None):
    global metric_df

    # Initialize
    rmse_scores, mae_scores, r2_scores, nse_scores = [], [], [], []
    all_predictions, all_true = [], []
    geo_cv_results = []

    kf = KFold(n_splits=cv, shuffle=True, random_state=42)
    fig, axes = plt.subplots(cv, 2, figsize=(12, 5 * cv))

    for fold, (train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]

        model = model_builder()
        model.fit(X_train, Y_train)
        predictions = model.predict(X_test)

        predictions_np = np.array(predictions).flatten()
        Y_test_np = np.array(Y_test).flatten()
        residuals = Y_test_np - predictions_np

        all_predictions.extend(predictions_np)
        all_true.extend(Y_test_np)

        # Compute metrics
        rmse = np.sqrt(mean_squared_error(Y_test_np, predictions_np))
        mae = mean_absolute_error(Y_test_np, predictions_np)
        r2 = r2_score(Y_test_np, predictions_np)
        # For NSE
        numerator = np.sum((Y_test_np - predictions_np)**2)
        denominator = np.sum((Y_test_np - np.mean(Y_test_np))**2)
        nse = 1 - (numerator / denominator)

        
        rmse_scores.append(rmse)
        mae_scores.append(mae)
        r2_scores.append(r2)
        nse_scores.append(nse)

        # Store fold-level results
        fold_df = pd.DataFrame({
            'Fold': fold + 1,
            'Observed': Y_test_np,
            'Predicted': predictions_np,
            'Residual': residuals
        }, index=Y_test.index)

        if coords is not None:
            fold_df = fold_df.merge(coords, left_index=True, right_index=True, how='left')

        geo_cv_results.append(fold_df)

        # Plot residuals
        axes[fold, 0].scatter(predictions_np, residuals, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
        axes[fold, 0].axhline(0, color='black', linestyle='dashed', linewidth=0.75)
        axes[fold, 0].set_xlim([0, 100])
        axes[fold, 0].set_ylim([-50, 50])
        axes[fold, 0].plot([100, 0], [0, 100], color='k', linestyle=':', linewidth=0.5)
        axes[fold, 0].plot([100, 0], [-100, 0], color='k', linestyle=':', linewidth=0.5)
        axes[fold, 0].set_title(f"Fold {fold+1} Residuals", fontname="Arial")
        axes[fold, 0].set_xlabel("Predicted Embeddedness (%)", fontname="Arial")
        axes[fold, 0].set_ylabel("Residuals (%)", fontname="Arial")

        # Plot predicted vs observed
        axes[fold, 1].scatter(Y_test_np, predictions_np, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
        axes[fold, 1].plot([0, 100], [0, 100], color="black", linestyle="--", linewidth=0.75)
        axes[fold, 1].set_xlim([0, 100])
        axes[fold, 1].set_ylim([0, 100])
        axes[fold, 1].set_title(f"Fold {fold+1} Predicted vs. Observed", fontname="Arial")
        axes[fold, 1].set_xlabel("Observed Embeddedness (%)", fontname="Arial")
        axes[fold, 1].set_ylabel("Predicted Embeddedness (%)", fontname="Arial")

        # Styling
        for ax in axes[fold]:
            ax.grid(False)
            for tick in ax.get_xticklabels() + ax.get_yticklabels():
                tick.set_fontname("Arial")

    plt.tight_layout()

    if save_path_figures:
        residuals_path = os.path.join(save_path_figures, f"{model_name}_cv_residuals.png")
        plt.savefig(residuals_path, dpi=300, bbox_inches='tight')
    plt.show()

    # Overall Predicted vs True
    plt.figure(figsize=(8, 5))
    plt.scatter(all_true, all_predictions, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
    plt.plot([min(all_true), max(all_true)], [min(all_true), max(all_true)], color="black", linestyle="-", linewidth=0.75, label='Perfect Fit (1:1)')
    plt.xlabel("Observed Embeddedness (%)", fontname="Arial", fontsize=14)
    plt.ylabel("Predicted Embeddedness (%)", fontname="Arial", fontsize=14)
    ax = plt.gca()
    ax.set_facecolor("white")
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(False)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontname("Arial")
        tick.set_fontsize(14)
    plt.tight_layout()
    plt.legend(fontsize=13)
    if save_path_figures:
        overall_pred_path = os.path.join(save_path_figures, f"{model_name}_overall_pred_vs_obs.png")
        plt.savefig(overall_pred_path, dpi=300, bbox_inches='tight')
    plt.show()

    # Overall residuals
    residuals_all = np.array(all_true) - np.array(all_predictions)
    print("The maximum residual is", round(np.abs(residuals_all).max(), 4), "% embeddedness.")
    print("The median residual is", round(np.median(np.abs(residuals_all)), 4), "% embeddedness.")
    print("The minimum residual is", round(np.abs(residuals_all).min(), 4), "% embeddedness.")

    plt.figure(figsize=(8, 5))
    plt.scatter(all_predictions, residuals_all, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
    plt.axhline(0, color='k', linestyle='-', linewidth=0.75, label='Perfect Fit (1:1)')
    plt.xlim([0, 100])
    plt.ylim([-50, 50])
    plt.plot([100, 0], [0, 100], color='k', linestyle=':', linewidth=0.5)
    plt.plot([100, 0], [-100, 0], color='k', linestyle=':', linewidth=0.5, label='Max Possible Residual')
    plt.xlabel("Predicted Embeddedness (%)", fontname="Arial", fontsize=14)
    plt.ylabel("Residuals (%)", fontname="Arial", fontsize=14)
    ax = plt.gca()
    ax.set_facecolor("white")
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(False)
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontname("Arial")
        tick.set_fontsize(14)
    plt.tight_layout()
    plt.legend(fontsize=13)
    if save_path_figures:
        overall_resid_path = os.path.join(save_path_figures, f"{model_name}_overall_residuals.png")
        plt.savefig(overall_resid_path, dpi=300, bbox_inches='tight')
    plt.show()

    # Residual threshold info
    residuals_above_20 = residuals_all[np.abs(residuals_all) <= 20]
    percent_above_20 = (len(residuals_above_20) / len(residuals_all)) * 100
    print(f'{percent_above_20}% of residuals are above 20%')

    # Save full GIS-ready results CSV
    all_geo_df = pd.concat(geo_cv_results)
    if save_path_csv:
        results_csv_path = os.path.join(save_path_csv, f"{model_name}_cv_predictions_with_coords.csv")
        all_geo_df.to_csv(results_csv_path, index=True)

    # Update global metrics
    new_row = pd.DataFrame({'Model': [model_name],
                            'CV RMSE': [np.mean(rmse_scores)],
                            'CV MAE': [np.mean(mae_scores)],
                            'CV R2' : [np.mean(r2_scores)],
                            'CV NSE': [np.mean(nse_scores)]})
    metric_df = pd.concat([metric_df, new_row], ignore_index=True)

    return metric_df, rmse_scores, mae_scores, r2_scores, nse_scores

# %%
# Separate function for FNN metric calcs and plotting
def manual_fnn_kfold_metrics(fnn_best_params, X, Y, cv=5, epochs=200, validation_split=0.2, patience=15):    
    global metric_df
    
    # Initialize empty lists
    fold_rmse = []
    fold_mae = []
    fold_r2 = []
    fold_nse = []
    
    all_predictions = []
    all_true = []
    
    kf = KFold(n_splits=cv, shuffle=True, random_state=42)
    
    fold_num = 1
    fig, axes = plt.subplots(cv, 2, figsize=(12, 5 * cv))
    
    for fold, (train_index, test_index) in enumerate(kf.split(X)):
        if hasattr(X, 'iloc'):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        else:
            X_train, X_test = X[train_index], X[test_index]
            
        if hasattr(Y, 'iloc'):
            Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
        else:
            Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Create a fresh FNN model for each fold
        model = fnn_build_model(fnn_best_params, input_shape=X_train.shape[1])
        
        # Define callbacks
        early_stop = EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
        clr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
        
        # Train model for each fold
        model.fit(
            X_train, Y_train,
            epochs=epochs,
            validation_split=validation_split,
            callbacks=[early_stop, clr],
            verbose=2
        )
        
        # Predict on the test fold
        preds = model.predict(X_test).flatten()
        Y_true = np.array(Y_test).flatten()
        
        all_predictions.extend(preds)
        all_true.extend(Y_true)
        
        # Calculate metrics for the fold
        rmse = np.sqrt(mean_squared_error(Y_true, preds))
        mae = mean_absolute_error(Y_true, preds)
        numerator = np.sum((Y_true - preds) **2)
        denominator = np.sum((Y_true - np.mean(Y_true))**2)
        r2 = r2_score(Y_true, preds)
        nse = 1 - (numerator / denominator)
        
        fold_rmse.append(rmse)
        fold_mae.append(mae)
        fold_r2.append(r2)
        fold_nse.append(nse)
        
        # Plot diagnostics for each fold
        plt.figure(figsize=(12, 5))
        
        # Residuals plot (Styled)
        axes[fold, 0].scatter(preds, Y_true-preds, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
        axes[fold, 0].axhline(0, color='black', linestyle='dashed', linewidth=0.75)
        axes[fold, 0].set_xlim([0, 100])
        axes[fold, 0].set_ylim([-50, 50])
        axes[fold, 0].plot([100, 0], [0, 100],
                         color = 'k',
                         linestyle = ':',
                         linewidth = 0.5)
        axes[fold, 0].plot([100, 0], [-100, 0],
                          color = 'k',
                         linestyle = ':',
                         linewidth = 0.5)
        axes[fold, 0].set_title(f"Fold {fold+1} Residuals", fontname="Arial")
        axes[fold, 0].set_xlabel("Predicted Embeddedness (%)", fontname="Arial")
        axes[fold, 0].set_ylabel("Residuals (%)", fontname="Arial")

        # Predicted vs Observed plot (Styled)
        axes[fold, 1].scatter(Y_true, preds, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
        axes[fold, 1].plot([min(Y_true), max(Y_true)], [min(Y_true), max(Y_true)], color="black", linestyle="--", linewidth=0.75)
        axes[fold, 1].set_xlim([0, 100])
        axes[fold, 1].set_ylim([0, 100])
        axes[fold, 1].set_title(f"Fold {fold+1} Predicted vs. Observed", fontname="Arial")
        axes[fold, 1].set_xlabel("Observed Embeddedness (%)", fontname="Arial")
        axes[fold, 1].set_ylabel("Predicted Embeddedness (%)", fontname="Arial")

        # Apply styling (remove grid, set fonts)
        for ax in axes[fold]:
            ax.grid(False)  # Remove grid
            for tick in ax.get_xticklabels() + ax.get_yticklabels():
                tick.set_fontname("Arial")
        
        plt.tight_layout()
        # plt.show()
        
        fold_num += 1
    
    # Overall Predicted vs. True across all folds (Styled)
    plt.figure(figsize=(8,5))
    plt.scatter(all_true, all_predictions, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
    plt.plot([min(all_true), max(all_true)], [min(all_true), max(all_true)], color="black", linestyle="--", linewidth=0.75, label = 'Perfect Fit (1:1)')
    plt.xlabel("Observed Embeddedness (%)", fontname="Arial")
    plt.ylabel("Predicted Embeddedness (%)", fontname="Arial")

    ax = plt.gca()
    ax.set_facecolor("white")
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(False)  # Remove grid
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontname("Arial")

    plt.tight_layout()
    plt.legend()

    plt.show()
    
    # Overall Residual Plot
    residuals_all = np.array(all_true) - np.array(all_predictions)
    
    # Print residual statistics
    print("The maximum residual is", round(np.abs(residuals_all).max(), 4), "% embeddedness.")
    print("The median residual is", round(np.median(np.abs(residuals_all)), 4), "% embeddedness.")
    print("The minimum residual is", round(np.abs(residuals_all).min(), 4), "% embeddedness.")
    
    plt.figure(figsize=(8,5))
    plt.scatter(all_predictions, residuals_all, color='darkorange', edgecolors='black', s=25, linewidths=0.5, alpha=0.5)
    plt.axhline(0, color='k', linestyle='dashed', linewidth=0.75)
    plt.xlim([0, 100])
    plt.ylim([-50, 50])
    plt.plot([100, 0], [0, 100],
                     color = 'k',
                     linestyle = '--',
                     linewidth = 0.5,
            label = 'Perfect Fit (1:1)')
    plt.plot([100, 0], [-100, 0],
                      color = 'k',
                     linestyle = ':',
                     linewidth = 0.5,
            label = 'Maximum Possible Residuals')
    plt.xlabel("Predicted Embeddedness (%)", fontname="Arial")
    plt.ylabel("Residuals (%)", fontname="Arial")

    ax = plt.gca()
    ax.set_facecolor("white")
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(False)  # Remove grid
    for tick in ax.get_xticklabels() + ax.get_yticklabels():
        tick.set_fontname("Arial")
    plt.tight_layout()
    plt.legend()

    plt.show()
    
    # Aggregate metrics over folds
    avg_rmse = np.mean(fold_rmse)
    avg_mae = np.mean(fold_mae)
    avg_r2 = np.mean(fold_r2)
    avg_nse = np.mean(fold_nse)
    
    metric_df = pd.DataFrame({
        'CV RMSE': [avg_rmse],
        'CV MAE': [avg_mae],
        'CV R2': [avg_r2],
        'CV NSE': [avg_nse]
    })
    
    return metric_df, fold_rmse, fold_mae, fold_r2, fold_nse

# %% [markdown]
# ### Step 3b. Model Building

# %% [markdown]
# #### Model 1. Random Forest Regressor (RFR)

# %%
############### MANUAL TRAINING OF RF ############
# Uncomment out for manual training

# # Define best hps
# rf_best_params = {
#     'n_estimators': 200, 
#     'max_depth': 25, 
#     'min_samples_split': 8, 
#     'min_samples_leaf': 2, 
#     'max_features': 'log2', 
#     'bootstrap': False
# }

# # Train best model with optimized hyperparameters
# rf_model = RandomForestRegressor(random_state = 42, **rf_best_params, n_jobs = -1)

# # Fit model on training data
# rf_model.fit(x_train_scld, y_train)

# %%
# Define the Optuna objective function
def rf_objective(trial):
    # Define search space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 500, step = 50),  
        "max_depth": trial.suggest_int("max_depth", 10, 50, step = 5),  
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),  
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5),  
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]), 
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False])
    }

    # Create RF model
    model = RandomForestRegressor(random_state = 42, **params, n_jobs = -1)

    # Perform cross-validation
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, 
                             x_train_scld, 
                             y_train, 
                             cv = kf, 
                             scoring = "neg_root_mean_squared_error", 
                             n_jobs = -1)

    # Return RMSE
    return np.mean(-scores)  

# Define study
rf_study = optuna.create_study(direction = "minimize", study_name = "RF_Optimization")

# Run optimization
rf_study.optimize(rf_objective, n_trials = 50, n_jobs = -1)

# Print best parameters
print("Best hyperparameters:", rf_study.best_params)

# Extract best hyperparameters
rf_best_params = rf_study.best_params

# Train best model with optimized hyperparameters
rf_model = RandomForestRegressor(random_state = 42, **rf_best_params, n_jobs = -1)

# Fit model on training data
rf_model.fit(x_train_scld, y_train)

# %%
# Use kfold metric function
metric_df, rf_rmse, rf_mae, rf_r2, rf_nse = kfold_model_metrics(
    model_name="RF",
    model_builder=lambda: RandomForestRegressor(
        random_state=42,
        **rf_best_params,
        n_jobs=-1
    ),
    X=x_scld,
    Y=y 
)

# %% [markdown]
# #### Model 2. Gradient Boosting Regressor (GBR)

# %%
############### MANUAL TRAINING OF GBR ############
# Uncomment below for training

# gbr_best_params = {"learning_rate":0.007171954175977735, 
#                "max_depth":8,
#                "max_features":'log2',
#                "min_samples_leaf":2,
#                "min_samples_split":3, 
#                "n_estimators":400,
#                "subsample":0.651869159957107}

# # Train best model with optimized hyperparameters
# gbr_model = GradientBoostingRegressor(random_state = 42, **gbr_best_params)

# # Fit model on full training data
# gbr_model.fit(x_train_scld, y_train)

# %%
# Define the Optuna objective function
def gbr_objective(trial):
    # Define search space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500, step = 50),
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.2, log = True),
        "max_depth": trial.suggest_int("max_depth", 2, 10), 
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 10), 
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5), 
        "subsample": trial.suggest_float("subsample", 0.4, 1.0), 
        "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2", None]),
    }

    # Create GBR model
    model = GradientBoostingRegressor(random_state = 42, **params)

    # Perform CV
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, x_train_scld, y_train, cv = kf, scoring = "neg_root_mean_squared_error")

    return np.mean(-scores)

# Create an Optuna study
gbr_study = optuna.create_study(direction= "minimize", study_name = "GBR_Optimization") # Minimizing RMSE!

# Run optimization
gbr_study.optimize(gbr_objective, n_trials = 50, n_jobs = -1)

# Extract best hyperparameters
gbr_best_params = gbr_study.best_params

# Train best model with optimized hyperparameters
gbr_model = GradientBoostingRegressor(random_state = 42, **gbr_best_params)

# Fit model on full training data
gbr_model.fit(x_train_scld, y_train)

# %%
# Use kfold metric function
metric_df, gbr_rmse, gbr_mae, gbr_r2, gbr_nse = kfold_model_metrics(
    model_name="GBR",
    model_builder=lambda: GradientBoostingRegressor(random_state=42, **gbr_best_params),
    X=x_scld,
    Y=y,   
    cv=5,
    coords=coords_df,
    save_path_figures=os.path.join(BASE_DIR, "usepa_nrsa", "results", "figures"),
    save_path_csv=os.path.join(BASE_DIR, "usepa_nrsa", "results")
)

# %% [markdown]
# ##### Optuna Plotting for Successful Algorithm

# %%
# Define best trials from Optuna study
best_trial = gbr_study.best_trial
best_params = best_trial.params  # Best hyperparameter combination
best_value = best_trial.value  # Best RMSE value
trials = gbr_study.trials_dataframe()
trials = trials[trials.state == "COMPLETE"]
trial_numbers = trials.number
objective_values = trials.value
best_trial_number = best_trial.number

# Find position in the dataset
best_x = trial_numbers[trial_numbers == best_trial_number].values[0]
best_y = best_value

# %%
# Extract trial numbers and objective values
trials = gbr_study.trials_dataframe()
trials = trials[trials.state == "COMPLETE"]
trial_numbers = trials.number
objective_values = trials.value

# Find best objective value over time
best_values = np.minimum.accumulate(objective_values)

# Plot objective value vs trial num
fig, ax = plt.subplots(figsize=(6, 4))

# Best value dotted line
ax.plot(trial_numbers, best_values, linestyle="dotted", color="black", linewidth=1, label="Best Value", zorder=2)

# Scatter plot for trials
sc = ax.scatter(
    trial_numbers, objective_values,
    color='darkorange', edgecolors='black', facecolors='darkorange', s=25,
    linewidths=0.5, alpha=0.7, label="Trial Objective Values",
    zorder=3
)
# Highlight the best trial
ax.scatter(best_x, best_y, color="white", edgecolors="black", s=150, marker="*", linewidths=1.5, label="Best Trial")

# Customizing aesthetics
ax.set_xlabel("Trial", fontsize=12, fontname="Arial", color="black")
ax.set_ylabel("Negative RMSE", fontsize=12, fontname="Arial", color="black")
ax.set_title("Optimization History of GBR", fontsize=14, fontname="Arial", color="black")

# Show legend
ax.legend(frameon=False, loc="best")
plt.tight_layout()

# Save for paper
opt_hist_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "figures", "us_optimization_history.png")
plt.savefig(opt_hist_path, dpi = 300)

# Display plot
plt.show()

# %%
# Get hyperparameter importance
importance = optuna.importance.get_param_importances(gbr_study)
params = list(importance.keys())
values = list(importance.values())

# Sort by importance (descending)
params, values = zip(*sorted(zip(params, values), key=lambda x: x[1], reverse=False))

# Create figure
fig, ax = plt.subplots(figsize=(6, 4))

# Horizontal bar plot
bars = ax.barh(params, values, color="darkorange", edgecolor="black", linewidth=0.7, alpha=0.7)

# Customizing aesthetics
ax.set_facecolor("white")
ax.set_xlabel("Importance", fontsize=12, fontname="Arial", color="black")
ax.set_ylabel("Hyperparameter", fontsize=12, fontname="Arial", color="black")
ax.set_title("Hyperparameter Importance for GBR", fontsize=14, fontname="Arial", color="black")

# Show exact importance values on bars
for bar, value in zip(bars, values):
    ax.text(
        bar.get_width() + 0.01, bar.get_y() + bar.get_height() / 2,
        f"{value:.3f}", ha="left", va="center", fontsize=10, fontname="Arial", color="black"
    )
plt.tight_layout()

# Save for paper
opt_imp_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "figures", "us_optimization_importance.png")
plt.savefig(opt_imp_path, dpi = 300)

# Show the plot
plt.show()

# %%
# Find best trial's hyperparameters (top importances)
best_trial = gbr_study.best_trial
best_x = best_trial.params["learning_rate"]
best_y = best_trial.params["n_estimators"]
best_value = best_trial.value  # Best RMSE

# %%
# Select hyperparameters to visualize
param_x_col = "params_learning_rate"
param_y_col = "params_n_estimators"

# Define x and y values
x = trials[param_x_col]
y = trials[param_y_col]
z = trials["value"]  # Objective function value

# Create a figure
fig, ax = plt.subplots(figsize=(6, 4))

# Create a grid for contouring
grid_x, grid_y = np.meshgrid(
    np.linspace(x.min(), x.max(), 100),
    np.linspace(y.min(), y.max(), 100)
)

# Interpolate the objective values for contour plotting
grid_z = griddata((x, y), z, (grid_x, grid_y), method="linear")

# Plot filled contours
contour = ax.contourf(grid_x, grid_y, grid_z, cmap="Oranges", alpha=0.7)
contour_lines = ax.contour(grid_x, grid_y, grid_z, colors="black", linewidths=0.5)

# Add color bar
cbar = plt.colorbar(contour)
cbar.set_label("Negative RMSE", fontsize=12, fontname="Arial", color="black")

# Scatter plot of actual trials
ax.scatter(x, y, color="darkorange", edgecolors="black", s=25, linewidths=0.5, alpha=0.7, label="Trials")

# Highlight the best trial
ax.scatter(best_x, best_y, color="white", edgecolors="black", s=150, marker="*", linewidths=1.5, label="Best Trial")

# Customizing aesthetics
ax.set_facecolor("white")
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.set_xlabel("Learning Rate", fontsize=12, fontname="Arial", color="black")
ax.set_ylabel("Number of Estimators", fontsize=12, fontname="Arial", color="black")
ax.set_title("Contour Plot of Learning Rate vs N Estimators", fontsize=14, fontname="Arial", color="black")

# Show legend
ax.legend(frameon=False)

# Save for paper
opt_contour_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "figures", "us_optimization_countour_plot.png")
plt.savefig(opt_contour_path, dpi = 300)

# Show the plot
plt.show()

# %% [markdown]
# #### Model 3. XGBoost

# %%
############# MANUAL TRAINING OF XGBOOST ############
# Uncomment below for training

# # Define best hps
# xgb_best_params = {
#     'n_estimators': 503, 
#     'learning_rate': 0.01610828468409669, 
#     'max_depth': 4, 
#     'subsample': 0.52173049518222, 
#     'colsample_bytree': 0.5828604193210032, 
#     'min_child_weight': 3, 
#     'reg_alpha': 0.03626374787052683, 
#     'reg_lambda': 0.9800260372662566, 
#     'gamma': 4.465706379070049, 
#     'scale_pos_weight': 1.0386877086310855
# }

# # Train best model
# xgb_model = xgb.XGBRegressor(
#     **xgb_best_params,
#     random_state = 42,
#     tree_method = "hist",
#     eval_metric = "rmse"
# )

# # Fit model on training data
# xgb_model.fit(x_train_scld, y_train)

# %%
# Define the objective function for Optuna
def xgb_objective(trial):
    # Define search  space
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 300, 600),
        "learning_rate": trial.suggest_float("learning_rate", 0.0005, 0.05, log=True),
        "max_depth": trial.suggest_int("max_depth", 2, 8),
        "subsample": trial.suggest_float("subsample", 0.4, 0.8),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.4, 0.8),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "reg_alpha": trial.suggest_float("reg_alpha", 0, 0.1), 
        "reg_lambda": trial.suggest_float("reg_lambda", 0.8, 1.5),  
        "gamma": trial.suggest_float("gamma", 0, 5),
        "scale_pos_weight": trial.suggest_float("scale_pos_weight", 0.8, 1.2),  
    }
    
    # Create model
    model = xgb.XGBRegressor(
        **params,
        random_state = 42,
        tree_method = "hist",
        eval_metric = "rmse",
        n_jobs = -1
    )
    
    # Perform CV
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, 
                             x_train_scld, 
                             y_train, 
                             cv = kf, 
                             scoring = "neg_root_mean_squared_error")
    
    return np.mean(-scores) # Minimize RMSE

# Create Optuna study
xgb_study = optuna.create_study(direction = "minimize", study_name = "XGB_Optimization")  # We want to minimize RMSE

# Run optimization
xgb_study.optimize(xgb_objective, n_trials = 50, n_jobs = -1)

# Print best parameters
print("Best hyperparameters:", xgb_study.best_params)
print("Best RMSE:", xgb_study.best_value)
                            
# Extract best hyperparameters
xgb_best_params = xgb_study.best_params

# Train best model! Woohoo!
xgb_model = xgb.XGBRegressor(
    **xgb_best_params,
    random_state = 42,
    tree_method = "hist",
    eval_metric = "rmse"
)

# Fit model on training data
xgb_model.fit(x_train_scld, y_train)

# %%
metric_df, xgb_rmse, xgb_mae, xgb_r2, xgb_nse = kfold_model_metrics(
    model_name="XGBoost",
    model_builder=lambda: xgb.XGBRegressor(
        **xgb_best_params,
        random_state=42,
        tree_method="hist",
        eval_metric="rmse"
    ),
    X=x_scld,
    Y=y
)
print(metric_df)

# %% [markdown]
# #### Model 4. FNN

# %%
######## MANUAL TRAINING OF FNN ############
# Uncomment below for training

# # Define best hps
# fnn_best_params = {
#     'learning_rate': 0.00044846566233004893, 
#     'batch_size': 32, 
#     'units_0': 128, 
#     'dropout_0': 0.2
# }

# # Build final model using extracted parameters
# fnn_model = fnn_build_model(fnn_best_params, input_shape=x_train_scld.shape[1])

# # Define learning rate scheduler
# clr = ReduceLROnPlateau(
#     monitor='val_loss',
#     factor=0.5,
#     patience=5,
#     min_lr=1e-6
# )

# # Train model
# history = fnn_model.fit(
#     x_train_scld, 
#     y_train, 
#     epochs=200,  
#     validation_split=0.2,  
#     callbacks=[EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True), clr],
#     verbose=2
# )

# %%
# Define FNN model building function
def fnn_build_model(best_params, input_shape):
    model = Sequential()
    model.add(Input(shape=(input_shape,)))
    
    # Single hidden layer
    model.add(Dense(units=best_params["units_0"], activation='relu', kernel_regularizer=l2(0.02)))
    model.add(BatchNormalization())
    model.add(Dropout(rate=best_params["dropout_0"]))
    
    # Output layer
    model.add(Dense(1, activation='linear'))
    
    model.compile(
        optimizer=Adam(learning_rate=best_params["learning_rate"]),
        loss="mean_squared_error"
    )
    
    return model

# %%
# Define FNN objective function
def fnn_objective(trial):
    params = {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 5e-4, log=True),
        "batch_size": trial.suggest_categorical("batch_size", [32, 64]),
        "units_0": trial.suggest_int("units_0", 32, 256, step=32),
        "dropout_0": trial.suggest_float("dropout_0", 0.2, 0.5, step=0.05)
    }

    # Manual 5-fold CV
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse_scores = []

    for train_index, val_index in kf.split(x_train_scld):
        X_train_fold, X_val_fold = x_train_scld.iloc[train_index], x_train_scld.iloc[val_index]
        y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

        # Build and train model
        model = fnn_build_model(params, input_shape=x_train_scld.shape[1])
        model.fit(
            X_train_fold, y_train_fold,
            epochs=100,
            batch_size=params["batch_size"],
            validation_data=(X_val_fold, y_val_fold),
            verbose=0
        )

        # Evaluate model
        y_pred = model.predict(X_val_fold)
        rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))  # RMSE
        rmse_scores.append(rmse)

    return np.mean(rmse_scores)

# %%
# Create Optuna study for FNN
fnn_study = optuna.create_study(direction="minimize", study_name="FNN_Optimized")
fnn_study.optimize(fnn_objective, n_trials=50, n_jobs=-1)
# Out:
# [I 2025-08-02 11:55:40,069] A new study created in memory with name: FNN_Optimized
# WARNING:tensorflow:5 out of the last 93 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x000002543F761620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002545BE64720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 2s 565ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002545BE64720> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 602ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 576ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 356ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 411ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 405ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 524ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 436ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 483ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 397ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 402ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 676ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 262ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 353ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 285ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 228ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 296ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 385ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 965ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 268ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step
# [I 2025-08-02 12:10:15,138] Trial 6 finished with value: 62.192484491160165 and parameters: {'learning_rate': 0.00012529860753840376, 'batch_size': 64, 'units_0': 32, 'dropout_0': 0.45}. Best is trial 6 with value: 62.192484491160165.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# [I 2025-08-02 12:10:48,270] Trial 11 finished with value: 64.22743002313831 and parameters: {'learning_rate': 1.1904933583270134e-05, 'batch_size': 64, 'units_0': 32, 'dropout_0': 0.35000000000000003}. Best is trial 6 with value: 62.192484491160165.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# [I 2025-08-02 12:10:50,498] Trial 20 finished with value: 60.82156530367105 and parameters: {'learning_rate': 8.143610149398968e-05, 'batch_size': 64, 'units_0': 160, 'dropout_0': 0.4}. Best is trial 20 with value: 60.82156530367105.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# [I 2025-08-02 12:11:23,820] Trial 15 finished with value: 20.120960461417003 and parameters: {'learning_rate': 0.000489998754376774, 'batch_size': 64, 'units_0': 192, 'dropout_0': 0.4}. Best is trial 15 with value: 20.120960461417003.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 3s 876ms/step
# [I 2025-08-02 12:11:38,617] Trial 3 finished with value: 62.7671937723808 and parameters: {'learning_rate': 3.098893126293316e-05, 'batch_size': 64, 'units_0': 160, 'dropout_0': 0.25}. Best is trial 15 with value: 20.120960461417003.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 389ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# [I 2025-08-02 12:11:40,797] Trial 13 finished with value: 63.62937281017497 and parameters: {'learning_rate': 1.5107536763470552e-05, 'batch_size': 64, 'units_0': 160, 'dropout_0': 0.30000000000000004}. Best is trial 15 with value: 20.120960461417003.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 417ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 428ms/step
# [I 2025-08-02 12:11:50,010] Trial 9 finished with value: 18.903022550709096 and parameters: {'learning_rate': 0.0004527492364406175, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.35000000000000003}. Best is trial 9 with value: 18.903022550709096.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step
# [I 2025-08-02 12:14:46,441] Trial 19 finished with value: 19.36717884443018 and parameters: {'learning_rate': 0.0003491986838534081, 'batch_size': 32, 'units_0': 96, 'dropout_0': 0.2}. Best is trial 9 with value: 18.903022550709096.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# [I 2025-08-02 12:15:13,235] Trial 10 finished with value: 60.1595032516819 and parameters: {'learning_rate': 7.714482127257945e-05, 'batch_size': 32, 'units_0': 64, 'dropout_0': 0.30000000000000004}. Best is trial 9 with value: 18.903022550709096.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# [I 2025-08-02 12:15:20,389] Trial 12 finished with value: 17.732519113956197 and parameters: {'learning_rate': 0.00044846566233004893, 'batch_size': 32, 'units_0': 128, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# [I 2025-08-02 12:15:21,085] Trial 18 finished with value: 52.85768471472461 and parameters: {'learning_rate': 0.00016601005464881942, 'batch_size': 32, 'units_0': 64, 'dropout_0': 0.45}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step
# [I 2025-08-02 12:15:22,919] Trial 2 finished with value: 26.333278843100963 and parameters: {'learning_rate': 0.0002619378653609627, 'batch_size': 32, 'units_0': 128, 'dropout_0': 0.4}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step
# [I 2025-08-02 12:15:34,618] Trial 0 finished with value: 24.07354293969642 and parameters: {'learning_rate': 0.00020636536550142578, 'batch_size': 32, 'units_0': 224, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 297ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step
# [I 2025-08-02 12:15:37,532] Trial 17 finished with value: 62.8752850631045 and parameters: {'learning_rate': 1.4294894330964939e-05, 'batch_size': 32, 'units_0': 192, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# [I 2025-08-02 12:15:37,597] Trial 1 finished with value: 61.21809703850496 and parameters: {'learning_rate': 3.2607226544174785e-05, 'batch_size': 32, 'units_0': 224, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step
# [I 2025-08-02 12:15:55,159] Trial 7 finished with value: 60.72243933318644 and parameters: {'learning_rate': 4.21121630176157e-05, 'batch_size': 32, 'units_0': 160, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step
# [I 2025-08-02 12:16:16,247] Trial 5 finished with value: 24.183296375049075 and parameters: {'learning_rate': 0.00038737877928723453, 'batch_size': 32, 'units_0': 64, 'dropout_0': 0.5}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step
# [I 2025-08-02 12:16:40,563] Trial 8 finished with value: 56.078348741144055 and parameters: {'learning_rate': 9.124440644052422e-05, 'batch_size': 32, 'units_0': 160, 'dropout_0': 0.4}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# [I 2025-08-02 12:16:43,209] Trial 16 finished with value: 56.82249526832167 and parameters: {'learning_rate': 0.00016807947642479798, 'batch_size': 32, 'units_0': 32, 'dropout_0': 0.45}. Best is trial 12 with value: 17.732519113956197.
# [I 2025-08-02 12:16:43,334] Trial 14 finished with value: 18.016542144140097 and parameters: {'learning_rate': 0.000330016457965144, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step
# [I 2025-08-02 12:16:48,882] Trial 21 finished with value: 61.664460375676754 and parameters: {'learning_rate': 3.8092855802486725e-05, 'batch_size': 32, 'units_0': 128, 'dropout_0': 0.35000000000000003}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 273ms/step
# [I 2025-08-02 12:16:51,242] Trial 4 finished with value: 61.25247912562797 and parameters: {'learning_rate': 2.783304577787914e-05, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 265ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 260ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 288ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 408ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 323ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 193ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step
# [I 2025-08-02 12:25:59,350] Trial 25 finished with value: 63.57326704651179 and parameters: {'learning_rate': 1.7020940156621282e-05, 'batch_size': 64, 'units_0': 128, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step
# [I 2025-08-02 12:26:25,691] Trial 27 finished with value: 63.655693868352444 and parameters: {'learning_rate': 1.7346186150875455e-05, 'batch_size': 64, 'units_0': 96, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step
# [I 2025-08-02 12:28:10,736] Trial 22 finished with value: 60.45308100064407 and parameters: {'learning_rate': 0.00010198019206276338, 'batch_size': 32, 'units_0': 32, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step
# [I 2025-08-02 12:28:37,312] Trial 29 finished with value: 41.63435364096389 and parameters: {'learning_rate': 0.0003510112017832583, 'batch_size': 64, 'units_0': 128, 'dropout_0': 0.5}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step
# [I 2025-08-02 12:28:49,034] Trial 23 finished with value: 62.77915114155219 and parameters: {'learning_rate': 1.7318637635386517e-05, 'batch_size': 32, 'units_0': 224, 'dropout_0': 0.45}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step
# [I 2025-08-02 12:29:17,639] Trial 24 finished with value: 57.418564988995364 and parameters: {'learning_rate': 9.574920036661479e-05, 'batch_size': 32, 'units_0': 96, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step
# [I 2025-08-02 12:29:42,452] Trial 36 finished with value: 18.54830161737761 and parameters: {'learning_rate': 0.0004940301695358292, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.5}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# [I 2025-08-02 12:29:54,172] Trial 37 finished with value: 34.59110347202646 and parameters: {'learning_rate': 0.00046735929963473806, 'batch_size': 64, 'units_0': 96, 'dropout_0': 0.5}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step
# [I 2025-08-02 12:29:56,084] Trial 35 finished with value: 18.538277925026705 and parameters: {'learning_rate': 0.0004990449825618538, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.5}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step
# [I 2025-08-02 12:30:26,705] Trial 38 finished with value: 55.446338695190875 and parameters: {'learning_rate': 0.0001444727882377243, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.35000000000000003}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
# [I 2025-08-02 12:30:47,024] Trial 28 finished with value: 57.85698907786508 and parameters: {'learning_rate': 8.032345146392566e-05, 'batch_size': 32, 'units_0': 128, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# [I 2025-08-02 12:31:02,011] Trial 26 finished with value: 33.16100483957858 and parameters: {'learning_rate': 0.00019454394724213053, 'batch_size': 32, 'units_0': 160, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [I 2025-08-02 12:31:12,146] Trial 40 finished with value: 47.05787922504463 and parameters: {'learning_rate': 0.00028640092320256867, 'batch_size': 64, 'units_0': 128, 'dropout_0': 0.35000000000000003}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# [I 2025-08-02 12:31:14,908] Trial 39 finished with value: 39.69468516402452 and parameters: {'learning_rate': 0.0002622085968970663, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.35000000000000003}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# [I 2025-08-02 12:31:28,640] Trial 43 finished with value: 34.56765001972268 and parameters: {'learning_rate': 0.0002838313549332784, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step
# [I 2025-08-02 12:31:36,487] Trial 42 finished with value: 30.69067976104135 and parameters: {'learning_rate': 0.0003052952058982017, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step
# [I 2025-08-02 12:32:20,530] Trial 30 finished with value: 56.27772529378812 and parameters: {'learning_rate': 7.530065732909133e-05, 'batch_size': 32, 'units_0': 224, 'dropout_0': 0.30000000000000004}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [I 2025-08-02 12:32:35,548] Trial 32 finished with value: 18.316692391216748 and parameters: {'learning_rate': 0.00024678255857732027, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# [I 2025-08-02 12:32:49,090] Trial 33 finished with value: 20.96941590087453 and parameters: {'learning_rate': 0.00021117892942345637, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step
# [I 2025-08-02 12:32:50,989] Trial 31 finished with value: 32.20670725526148 and parameters: {'learning_rate': 0.00016955980439365627, 'batch_size': 32, 'units_0': 224, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# [I 2025-08-02 12:32:52,077] Trial 34 finished with value: 17.908674250361475 and parameters: {'learning_rate': 0.0004792782834886619, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [I 2025-08-02 12:33:31,803] Trial 41 finished with value: 18.003849434530444 and parameters: {'learning_rate': 0.0002841453879933606, 'batch_size': 32, 'units_0': 256, 'dropout_0': 0.2}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [I 2025-08-02 12:35:37,227] Trial 44 finished with value: 18.172356826042815 and parameters: {'learning_rate': 0.0004954966472026182, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [I 2025-08-02 12:35:43,318] Trial 45 finished with value: 32.17699257613868 and parameters: {'learning_rate': 0.00030047396037368156, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [I 2025-08-02 12:35:58,053] Trial 46 finished with value: 18.182393411972 and parameters: {'learning_rate': 0.0004937997687681452, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [I 2025-08-02 12:36:05,891] Trial 47 finished with value: 18.322315632240283 and parameters: {'learning_rate': 0.0004769735354018652, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [I 2025-08-02 12:36:09,347] Trial 48 finished with value: 18.172147498517838 and parameters: {'learning_rate': 0.0004992483960810081, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [I 2025-08-02 12:36:21,050] Trial 49 finished with value: 39.697719360484705 and parameters: {'learning_rate': 0.000251749686982717, 'batch_size': 64, 'units_0': 256, 'dropout_0': 0.25}. Best is trial 12 with value: 17.732519113956197.

# %%
# Extract best parameters
fnn_best_params = fnn_study.best_params

# Print results
print(fnn_best_params)
# Out:
# {'learning_rate': 0.00044846566233004893, 'batch_size': 32, 'units_0': 128, 'dropout_0': 0.2}

# %%
# Build final model using extracted parameters
fnn_model = fnn_build_model(fnn_best_params, input_shape=x_train_scld.shape[1])

# Define learning rate scheduler
clr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

# Train model
history = fnn_model.fit(
    x_train_scld, 
    y_train, 
    epochs=200,  
    validation_split=0.2,  
    callbacks=[EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True), clr],
    verbose=2
)
# Out:
# Epoch 1/200
# 20/20 - 3s - 151ms/step - loss: 4177.6821 - val_loss: 4001.0520 - learning_rate: 4.4847e-04
# Epoch 2/200
# 20/20 - 0s - 17ms/step - loss: 4117.8110 - val_loss: 3974.2163 - learning_rate: 4.4847e-04
# Epoch 3/200
# 20/20 - 1s - 33ms/step - loss: 4082.6123 - val_loss: 3944.8835 - learning_rate: 4.4847e-04
# Epoch 4/200
# 20/20 - 0s - 15ms/step - loss: 4035.6682 - val_loss: 3913.8394 - learning_rate: 4.4847e-04
# Epoch 5/200
# 20/20 - 0s - 16ms/step - loss: 3991.7378 - val_loss: 3879.0305 - learning_rate: 4.4847e-04
# Epoch 6/200
# 20/20 - 0s - 17ms/step - loss: 3954.5293 - val_loss: 3841.5173 - learning_rate: 4.4847e-04
# Epoch 7/200
# 20/20 - 0s - 22ms/step - loss: 3907.2715 - val_loss: 3799.8767 - learning_rate: 4.4847e-04
# Epoch 8/200
# 20/20 - 0s - 14ms/step - loss: 3865.6228 - val_loss: 3754.9285 - learning_rate: 4.4847e-04
# Epoch 9/200
# 20/20 - 0s - 17ms/step - loss: 3817.0093 - val_loss: 3704.1838 - learning_rate: 4.4847e-04
# Epoch 10/200
# 20/20 - 1s - 31ms/step - loss: 3763.1082 - val_loss: 3650.2585 - learning_rate: 4.4847e-04
# Epoch 11/200
# 20/20 - 0s - 17ms/step - loss: 3723.9329 - val_loss: 3590.7708 - learning_rate: 4.4847e-04
# Epoch 12/200
# 20/20 - 0s - 17ms/step - loss: 3674.5298 - val_loss: 3531.1519 - learning_rate: 4.4847e-04
# Epoch 13/200
# 20/20 - 0s - 16ms/step - loss: 3620.7915 - val_loss: 3473.2224 - learning_rate: 4.4847e-04
# Epoch 14/200
# 20/20 - 0s - 17ms/step - loss: 3570.1565 - val_loss: 3409.5925 - learning_rate: 4.4847e-04
# Epoch 15/200
# 20/20 - 0s - 15ms/step - loss: 3513.5674 - val_loss: 3354.2732 - learning_rate: 4.4847e-04
# Epoch 16/200
# 20/20 - 0s - 16ms/step - loss: 3463.0442 - val_loss: 3287.0261 - learning_rate: 4.4847e-04
# Epoch 17/200
# 20/20 - 0s - 17ms/step - loss: 3401.2070 - val_loss: 3224.0391 - learning_rate: 4.4847e-04
# Epoch 18/200
# 20/20 - 0s - 16ms/step - loss: 3344.9204 - val_loss: 3160.8140 - learning_rate: 4.4847e-04
# Epoch 19/200
# 20/20 - 0s - 17ms/step - loss: 3292.6077 - val_loss: 3097.1890 - learning_rate: 4.4847e-04
# Epoch 20/200
# 20/20 - 0s - 17ms/step - loss: 3217.5334 - val_loss: 3033.7515 - learning_rate: 4.4847e-04
# Epoch 21/200
# 20/20 - 0s - 17ms/step - loss: 3138.9482 - val_loss: 2965.4639 - learning_rate: 4.4847e-04
# Epoch 22/200
# 20/20 - 0s - 14ms/step - loss: 3098.9888 - val_loss: 2907.1238 - learning_rate: 4.4847e-04
# Epoch 23/200
# 20/20 - 0s - 17ms/step - loss: 3008.5928 - val_loss: 2841.3120 - learning_rate: 4.4847e-04
# Epoch 24/200
# 20/20 - 0s - 16ms/step - loss: 2927.5483 - val_loss: 2767.0989 - learning_rate: 4.4847e-04
# Epoch 25/200
# 20/20 - 0s - 18ms/step - loss: 2862.5569 - val_loss: 2690.0342 - learning_rate: 4.4847e-04
# Epoch 26/200
# 20/20 - 0s - 15ms/step - loss: 2784.3975 - val_loss: 2618.7085 - learning_rate: 4.4847e-04
# Epoch 27/200
# 20/20 - 0s - 17ms/step - loss: 2685.6450 - val_loss: 2547.2998 - learning_rate: 4.4847e-04
# Epoch 28/200
# 20/20 - 0s - 16ms/step - loss: 2609.3809 - val_loss: 2477.3728 - learning_rate: 4.4847e-04
# Epoch 29/200
# 20/20 - 0s - 18ms/step - loss: 2532.9189 - val_loss: 2390.4102 - learning_rate: 4.4847e-04
# Epoch 30/200
# 20/20 - 0s - 15ms/step - loss: 2450.6648 - val_loss: 2299.3708 - learning_rate: 4.4847e-04
# Epoch 31/200
# 20/20 - 0s - 17ms/step - loss: 2342.4058 - val_loss: 2223.3259 - learning_rate: 4.4847e-04
# Epoch 32/200
# 20/20 - 0s - 16ms/step - loss: 2262.9761 - val_loss: 2140.5862 - learning_rate: 4.4847e-04
# Epoch 33/200
# 20/20 - 0s - 15ms/step - loss: 2175.1453 - val_loss: 2045.2963 - learning_rate: 4.4847e-04
# Epoch 34/200
# 20/20 - 0s - 15ms/step - loss: 2078.0469 - val_loss: 1954.0989 - learning_rate: 4.4847e-04
# Epoch 35/200
# 20/20 - 0s - 20ms/step - loss: 2000.7024 - val_loss: 1868.8695 - learning_rate: 4.4847e-04
# Epoch 36/200
# 20/20 - 0s - 15ms/step - loss: 1906.9639 - val_loss: 1781.8793 - learning_rate: 4.4847e-04
# Epoch 37/200
# 20/20 - 0s - 16ms/step - loss: 1831.1005 - val_loss: 1698.5547 - learning_rate: 4.4847e-04
# Epoch 38/200
# 20/20 - 0s - 16ms/step - loss: 1728.7478 - val_loss: 1617.8054 - learning_rate: 4.4847e-04
# Epoch 39/200
# 20/20 - 0s - 15ms/step - loss: 1646.9265 - val_loss: 1535.0623 - learning_rate: 4.4847e-04
# Epoch 40/200
# 20/20 - 0s - 18ms/step - loss: 1563.5908 - val_loss: 1459.6937 - learning_rate: 4.4847e-04
# Epoch 41/200
# 20/20 - 1s - 29ms/step - loss: 1501.6754 - val_loss: 1382.0787 - learning_rate: 4.4847e-04
# Epoch 42/200
# 20/20 - 0s - 16ms/step - loss: 1401.9242 - val_loss: 1303.1251 - learning_rate: 4.4847e-04
# Epoch 43/200
# 20/20 - 0s - 17ms/step - loss: 1326.5151 - val_loss: 1233.6714 - learning_rate: 4.4847e-04
# Epoch 44/200
# 20/20 - 0s - 18ms/step - loss: 1225.0146 - val_loss: 1168.1986 - learning_rate: 4.4847e-04
# Epoch 45/200
# 20/20 - 0s - 15ms/step - loss: 1181.7533 - val_loss: 1108.5353 - learning_rate: 4.4847e-04
# Epoch 46/200
# 20/20 - 0s - 18ms/step - loss: 1115.0610 - val_loss: 1041.4210 - learning_rate: 4.4847e-04
# Epoch 47/200
# 20/20 - 0s - 16ms/step - loss: 1024.7585 - val_loss: 977.2788 - learning_rate: 4.4847e-04
# Epoch 48/200
# 20/20 - 0s - 17ms/step - loss: 978.5214 - val_loss: 921.6960 - learning_rate: 4.4847e-04
# Epoch 49/200
# 20/20 - 0s - 17ms/step - loss: 921.9378 - val_loss: 863.1140 - learning_rate: 4.4847e-04
# Epoch 50/200
# 20/20 - 0s - 17ms/step - loss: 850.6925 - val_loss: 814.1506 - learning_rate: 4.4847e-04
# Epoch 51/200
# 20/20 - 0s - 16ms/step - loss: 790.8509 - val_loss: 768.1618 - learning_rate: 4.4847e-04
# Epoch 52/200
# 20/20 - 0s - 17ms/step - loss: 739.0029 - val_loss: 721.0497 - learning_rate: 4.4847e-04
# Epoch 53/200
# 20/20 - 0s - 16ms/step - loss: 696.5819 - val_loss: 683.1248 - learning_rate: 4.4847e-04
# Epoch 54/200
# 20/20 - 0s - 16ms/step - loss: 646.4271 - val_loss: 647.8598 - learning_rate: 4.4847e-04
# Epoch 55/200
# 20/20 - 0s - 17ms/step - loss: 642.6068 - val_loss: 612.7678 - learning_rate: 4.4847e-04
# Epoch 56/200
# 20/20 - 0s - 15ms/step - loss: 561.3287 - val_loss: 592.4637 - learning_rate: 4.4847e-04
# Epoch 57/200
# 20/20 - 0s - 16ms/step - loss: 536.3267 - val_loss: 565.1384 - learning_rate: 4.4847e-04
# Epoch 58/200
# 20/20 - 0s - 17ms/step - loss: 496.2803 - val_loss: 534.2263 - learning_rate: 4.4847e-04
# Epoch 59/200
# 20/20 - 0s - 16ms/step - loss: 470.6719 - val_loss: 514.6006 - learning_rate: 4.4847e-04
# Epoch 60/200
# 20/20 - 0s - 17ms/step - loss: 441.4607 - val_loss: 490.9430 - learning_rate: 4.4847e-04
# Epoch 61/200
# 20/20 - 0s - 15ms/step - loss: 419.4948 - val_loss: 476.0365 - learning_rate: 4.4847e-04
# Epoch 62/200
# 20/20 - 0s - 16ms/step - loss: 401.9264 - val_loss: 458.0946 - learning_rate: 4.4847e-04
# Epoch 63/200
# 20/20 - 0s - 16ms/step - loss: 367.7226 - val_loss: 441.9540 - learning_rate: 4.4847e-04
# Epoch 64/200
# 20/20 - 0s - 16ms/step - loss: 367.7847 - val_loss: 427.0064 - learning_rate: 4.4847e-04
# Epoch 65/200
# 20/20 - 0s - 16ms/step - loss: 338.3789 - val_loss: 413.9186 - learning_rate: 4.4847e-04
# Epoch 66/200
# 20/20 - 0s - 17ms/step - loss: 337.3081 - val_loss: 404.1519 - learning_rate: 4.4847e-04
# Epoch 67/200
# 20/20 - 0s - 18ms/step - loss: 303.2587 - val_loss: 398.3325 - learning_rate: 4.4847e-04
# Epoch 68/200
# 20/20 - 0s - 16ms/step - loss: 303.1190 - val_loss: 394.0081 - learning_rate: 4.4847e-04
# Epoch 69/200
# 20/20 - 0s - 15ms/step - loss: 283.9827 - val_loss: 387.1162 - learning_rate: 4.4847e-04
# Epoch 70/200
# 20/20 - 0s - 18ms/step - loss: 269.2061 - val_loss: 380.3213 - learning_rate: 4.4847e-04
# Epoch 71/200
# 20/20 - 0s - 15ms/step - loss: 286.8609 - val_loss: 374.0694 - learning_rate: 4.4847e-04
# Epoch 72/200
# 20/20 - 0s - 14ms/step - loss: 273.1424 - val_loss: 368.7414 - learning_rate: 4.4847e-04
# Epoch 73/200
# 20/20 - 0s - 15ms/step - loss: 272.5336 - val_loss: 366.7427 - learning_rate: 4.4847e-04
# Epoch 74/200
# 20/20 - 0s - 17ms/step - loss: 255.7993 - val_loss: 362.6579 - learning_rate: 4.4847e-04
# Epoch 75/200
# 20/20 - 0s - 17ms/step - loss: 269.3181 - val_loss: 364.5442 - learning_rate: 4.4847e-04
# Epoch 76/200
# 20/20 - 0s - 17ms/step - loss: 246.6717 - val_loss: 364.5167 - learning_rate: 4.4847e-04
# Epoch 77/200
# 20/20 - 0s - 16ms/step - loss: 239.2210 - val_loss: 362.5135 - learning_rate: 4.4847e-04
# Epoch 78/200
# 20/20 - 0s - 17ms/step - loss: 261.6346 - val_loss: 359.2499 - learning_rate: 4.4847e-04
# Epoch 79/200
# 20/20 - 1s - 31ms/step - loss: 243.0087 - val_loss: 359.6919 - learning_rate: 4.4847e-04
# Epoch 80/200
# 20/20 - 0s - 18ms/step - loss: 244.7834 - val_loss: 360.1189 - learning_rate: 4.4847e-04
# Epoch 81/200
# 20/20 - 0s - 18ms/step - loss: 236.9499 - val_loss: 361.5857 - learning_rate: 4.4847e-04
# Epoch 82/200
# 20/20 - 0s - 16ms/step - loss: 239.2628 - val_loss: 360.3107 - learning_rate: 4.4847e-04
# Epoch 83/200
# 20/20 - 0s - 16ms/step - loss: 223.4438 - val_loss: 359.5844 - learning_rate: 4.4847e-04
# Epoch 84/200
# 20/20 - 0s - 17ms/step - loss: 230.5672 - val_loss: 362.0648 - learning_rate: 2.2423e-04
# Epoch 85/200
# 20/20 - 0s - 15ms/step - loss: 227.6548 - val_loss: 362.6573 - learning_rate: 2.2423e-04
# Epoch 86/200
# 20/20 - 0s - 16ms/step - loss: 225.1779 - val_loss: 364.6608 - learning_rate: 2.2423e-04
# Epoch 87/200
# 20/20 - 0s - 15ms/step - loss: 235.8105 - val_loss: 363.4038 - learning_rate: 2.2423e-04
# Epoch 88/200
# 20/20 - 0s - 17ms/step - loss: 231.9896 - val_loss: 364.3123 - learning_rate: 2.2423e-04
# Epoch 89/200
# 20/20 - 0s - 16ms/step - loss: 245.5066 - val_loss: 363.4319 - learning_rate: 1.1212e-04
# Epoch 90/200
# 20/20 - 0s - 18ms/step - loss: 234.2726 - val_loss: 362.8111 - learning_rate: 1.1212e-04
# Epoch 91/200
# 20/20 - 0s - 17ms/step - loss: 240.7090 - val_loss: 363.2168 - learning_rate: 1.1212e-04
# Epoch 92/200
# 20/20 - 0s - 18ms/step - loss: 227.4653 - val_loss: 364.7933 - learning_rate: 1.1212e-04
# Epoch 93/200
# 20/20 - 0s - 18ms/step - loss: 242.8195 - val_loss: 364.6090 - learning_rate: 1.1212e-04

# %%
# Use manual kfold function
metric_df, fnn_rmse, fnn_mae, fnn_r2, fnn_nse = manual_fnn_kfold_metrics(
    fnn_best_params, # from Optuna
    X=x_train_scld,
    Y=y_train,
    cv=5,
    epochs=200,
    validation_split=0.2,
    patience=15
)
# Out:
# Epoch 1/200
# 16/16 - 3s - 174ms/step - loss: 4220.3672 - val_loss: 4146.9043 - learning_rate: 4.4847e-04
# Epoch 2/200
# 16/16 - 0s - 22ms/step - loss: 4182.3862 - val_loss: 4125.0977 - learning_rate: 4.4847e-04
# Epoch 3/200
# 16/16 - 0s - 18ms/step - loss: 4146.1528 - val_loss: 4101.4136 - learning_rate: 4.4847e-04
# Epoch 4/200
# 16/16 - 0s - 21ms/step - loss: 4108.4409 - val_loss: 4077.1340 - learning_rate: 4.4847e-04
# Epoch 5/200
# 16/16 - 0s - 21ms/step - loss: 4067.4275 - val_loss: 4050.5935 - learning_rate: 4.4847e-04
# Epoch 6/200
# 16/16 - 0s - 21ms/step - loss: 4033.1914 - val_loss: 4022.9290 - learning_rate: 4.4847e-04
# Epoch 7/200
# 16/16 - 0s - 21ms/step - loss: 3998.9170 - val_loss: 3991.7927 - learning_rate: 4.4847e-04
# Epoch 8/200
# 16/16 - 0s - 21ms/step - loss: 3966.4641 - val_loss: 3958.1628 - learning_rate: 4.4847e-04
# Epoch 9/200
# 16/16 - 0s - 20ms/step - loss: 3936.1973 - val_loss: 3922.2598 - learning_rate: 4.4847e-04
# Epoch 10/200
# 16/16 - 0s - 18ms/step - loss: 3897.7471 - val_loss: 3884.7207 - learning_rate: 4.4847e-04
# Epoch 11/200
# 16/16 - 0s - 19ms/step - loss: 3862.3706 - val_loss: 3844.8604 - learning_rate: 4.4847e-04
# Epoch 12/200
# 16/16 - 0s - 21ms/step - loss: 3815.2070 - val_loss: 3804.5713 - learning_rate: 4.4847e-04
# Epoch 13/200
# 16/16 - 0s - 18ms/step - loss: 3772.8818 - val_loss: 3762.3535 - learning_rate: 4.4847e-04
# Epoch 14/200
# 16/16 - 0s - 17ms/step - loss: 3737.5979 - val_loss: 3714.0293 - learning_rate: 4.4847e-04
# Epoch 15/200
# 16/16 - 0s - 23ms/step - loss: 3707.0801 - val_loss: 3666.0776 - learning_rate: 4.4847e-04
# Epoch 16/200
# 16/16 - 0s - 20ms/step - loss: 3663.9417 - val_loss: 3616.9487 - learning_rate: 4.4847e-04
# Epoch 17/200
# 16/16 - 0s - 20ms/step - loss: 3622.0784 - val_loss: 3567.1118 - learning_rate: 4.4847e-04
# Epoch 18/200
# 16/16 - 0s - 21ms/step - loss: 3574.3079 - val_loss: 3519.5422 - learning_rate: 4.4847e-04
# Epoch 19/200
# 16/16 - 0s - 22ms/step - loss: 3539.0806 - val_loss: 3472.5354 - learning_rate: 4.4847e-04
# Epoch 20/200
# 16/16 - 0s - 17ms/step - loss: 3476.1121 - val_loss: 3421.8013 - learning_rate: 4.4847e-04
# Epoch 21/200
# 16/16 - 0s - 18ms/step - loss: 3436.2764 - val_loss: 3377.1738 - learning_rate: 4.4847e-04
# Epoch 22/200
# 16/16 - 0s - 20ms/step - loss: 3393.7083 - val_loss: 3321.9048 - learning_rate: 4.4847e-04
# Epoch 23/200
# 16/16 - 0s - 21ms/step - loss: 3337.8459 - val_loss: 3272.8035 - learning_rate: 4.4847e-04
# Epoch 24/200
# 16/16 - 0s - 18ms/step - loss: 3303.3008 - val_loss: 3226.3547 - learning_rate: 4.4847e-04
# Epoch 25/200
# 16/16 - 0s - 20ms/step - loss: 3229.4199 - val_loss: 3167.4277 - learning_rate: 4.4847e-04
# Epoch 26/200
# 16/16 - 0s - 21ms/step - loss: 3199.1233 - val_loss: 3114.5955 - learning_rate: 4.4847e-04
# Epoch 27/200
# 16/16 - 0s - 20ms/step - loss: 3114.1772 - val_loss: 3061.1472 - learning_rate: 4.4847e-04
# Epoch 28/200
# 16/16 - 0s - 20ms/step - loss: 3071.9373 - val_loss: 3007.1794 - learning_rate: 4.4847e-04
# Epoch 29/200
# 16/16 - 0s - 21ms/step - loss: 3022.2385 - val_loss: 2946.2502 - learning_rate: 4.4847e-04
# Epoch 30/200
# 16/16 - 0s - 19ms/step - loss: 2952.1990 - val_loss: 2889.7327 - learning_rate: 4.4847e-04
# Epoch 31/200
# 16/16 - 0s - 21ms/step - loss: 2894.0503 - val_loss: 2831.0098 - learning_rate: 4.4847e-04
# Epoch 32/200
# 16/16 - 0s - 20ms/step - loss: 2821.4910 - val_loss: 2773.6099 - learning_rate: 4.4847e-04
# Epoch 33/200
# 16/16 - 0s - 18ms/step - loss: 2742.8599 - val_loss: 2716.1880 - learning_rate: 4.4847e-04
# Epoch 34/200
# 16/16 - 0s - 21ms/step - loss: 2701.5015 - val_loss: 2655.6743 - learning_rate: 4.4847e-04
# Epoch 35/200
# 16/16 - 1s - 40ms/step - loss: 2599.4009 - val_loss: 2588.1025 - learning_rate: 4.4847e-04
# Epoch 36/200
# 16/16 - 0s - 20ms/step - loss: 2551.7529 - val_loss: 2512.2959 - learning_rate: 4.4847e-04
# Epoch 37/200
# 16/16 - 0s - 18ms/step - loss: 2489.7285 - val_loss: 2439.4922 - learning_rate: 4.4847e-04
# Epoch 38/200
# 16/16 - 0s - 21ms/step - loss: 2411.1106 - val_loss: 2374.0442 - learning_rate: 4.4847e-04
# Epoch 39/200
# 16/16 - 0s - 19ms/step - loss: 2333.0027 - val_loss: 2318.2773 - learning_rate: 4.4847e-04
# Epoch 40/200
# 16/16 - 0s - 17ms/step - loss: 2255.7009 - val_loss: 2258.9456 - learning_rate: 4.4847e-04
# Epoch 41/200
# 16/16 - 0s - 21ms/step - loss: 2216.1292 - val_loss: 2194.3435 - learning_rate: 4.4847e-04
# Epoch 42/200
# 16/16 - 0s - 20ms/step - loss: 2121.5210 - val_loss: 2121.6318 - learning_rate: 4.4847e-04
# Epoch 43/200
# 16/16 - 0s - 17ms/step - loss: 2035.3085 - val_loss: 2041.9465 - learning_rate: 4.4847e-04
# Epoch 44/200
# 16/16 - 0s - 21ms/step - loss: 1979.3346 - val_loss: 1977.5621 - learning_rate: 4.4847e-04
# Epoch 45/200
# 16/16 - 0s - 21ms/step - loss: 1918.8809 - val_loss: 1909.6309 - learning_rate: 4.4847e-04
# Epoch 46/200
# 16/16 - 0s - 19ms/step - loss: 1827.9786 - val_loss: 1845.5792 - learning_rate: 4.4847e-04
# Epoch 47/200
# 16/16 - 0s - 20ms/step - loss: 1759.8087 - val_loss: 1777.8132 - learning_rate: 4.4847e-04
# Epoch 48/200
# 16/16 - 0s - 22ms/step - loss: 1681.9612 - val_loss: 1716.6364 - learning_rate: 4.4847e-04
# Epoch 49/200
# 16/16 - 0s - 20ms/step - loss: 1584.8938 - val_loss: 1647.3588 - learning_rate: 4.4847e-04
# Epoch 50/200
# 16/16 - 0s - 22ms/step - loss: 1571.6836 - val_loss: 1583.1666 - learning_rate: 4.4847e-04
# Epoch 51/200
# 16/16 - 0s - 19ms/step - loss: 1502.1945 - val_loss: 1522.1334 - learning_rate: 4.4847e-04
# Epoch 52/200
# 16/16 - 0s - 21ms/step - loss: 1436.5602 - val_loss: 1458.9673 - learning_rate: 4.4847e-04
# Epoch 53/200
# 16/16 - 0s - 20ms/step - loss: 1346.5789 - val_loss: 1396.4375 - learning_rate: 4.4847e-04
# Epoch 54/200
# 16/16 - 0s - 22ms/step - loss: 1293.0033 - val_loss: 1335.8727 - learning_rate: 4.4847e-04
# Epoch 55/200
# 16/16 - 0s - 19ms/step - loss: 1236.1599 - val_loss: 1279.6359 - learning_rate: 4.4847e-04
# Epoch 56/200
# 16/16 - 0s - 19ms/step - loss: 1166.9312 - val_loss: 1224.4851 - learning_rate: 4.4847e-04
# Epoch 57/200
# 16/16 - 0s - 21ms/step - loss: 1119.1753 - val_loss: 1171.7814 - learning_rate: 4.4847e-04
# Epoch 58/200
# 16/16 - 0s - 20ms/step - loss: 1064.5367 - val_loss: 1121.2385 - learning_rate: 4.4847e-04
# Epoch 59/200
# 16/16 - 0s - 22ms/step - loss: 1008.3745 - val_loss: 1073.6287 - learning_rate: 4.4847e-04
# Epoch 60/200
# 16/16 - 0s - 20ms/step - loss: 957.8838 - val_loss: 1023.7372 - learning_rate: 4.4847e-04
# Epoch 61/200
# 16/16 - 0s - 18ms/step - loss: 912.8165 - val_loss: 979.6999 - learning_rate: 4.4847e-04
# Epoch 62/200
# 16/16 - 0s - 17ms/step - loss: 849.5418 - val_loss: 935.4979 - learning_rate: 4.4847e-04
# Epoch 63/200
# 16/16 - 0s - 22ms/step - loss: 837.5605 - val_loss: 902.0142 - learning_rate: 4.4847e-04
# Epoch 64/200
# 16/16 - 0s - 20ms/step - loss: 769.4072 - val_loss: 862.4155 - learning_rate: 4.4847e-04
# Epoch 65/200
# 16/16 - 0s - 18ms/step - loss: 729.0844 - val_loss: 829.1718 - learning_rate: 4.4847e-04
# Epoch 66/200
# 16/16 - 0s - 21ms/step - loss: 710.3682 - val_loss: 793.8096 - learning_rate: 4.4847e-04
# Epoch 67/200
# 16/16 - 0s - 22ms/step - loss: 644.7704 - val_loss: 755.8942 - learning_rate: 4.4847e-04
# Epoch 68/200
# 16/16 - 0s - 20ms/step - loss: 626.7689 - val_loss: 728.6180 - learning_rate: 4.4847e-04
# Epoch 69/200
# 16/16 - 0s - 23ms/step - loss: 583.4888 - val_loss: 704.5383 - learning_rate: 4.4847e-04
# Epoch 70/200
# 16/16 - 0s - 21ms/step - loss: 558.5973 - val_loss: 676.2234 - learning_rate: 4.4847e-04
# Epoch 71/200
# 16/16 - 0s - 19ms/step - loss: 538.9074 - val_loss: 648.0502 - learning_rate: 4.4847e-04
# Epoch 72/200
# 16/16 - 0s - 19ms/step - loss: 496.5075 - val_loss: 625.8015 - learning_rate: 4.4847e-04
# Epoch 73/200
# 16/16 - 0s - 19ms/step - loss: 472.6478 - val_loss: 602.0118 - learning_rate: 4.4847e-04
# Epoch 74/200
# 16/16 - 0s - 21ms/step - loss: 457.9822 - val_loss: 581.4469 - learning_rate: 4.4847e-04
# Epoch 75/200
# 16/16 - 0s - 18ms/step - loss: 442.9082 - val_loss: 563.0200 - learning_rate: 4.4847e-04
# Epoch 76/200
# 16/16 - 0s - 21ms/step - loss: 407.0007 - val_loss: 548.4074 - learning_rate: 4.4847e-04
# Epoch 77/200
# 16/16 - 0s - 20ms/step - loss: 384.5563 - val_loss: 535.1746 - learning_rate: 4.4847e-04
# Epoch 78/200
# 16/16 - 0s - 19ms/step - loss: 376.4050 - val_loss: 517.9579 - learning_rate: 4.4847e-04
# Epoch 79/200
# 16/16 - 0s - 19ms/step - loss: 364.7127 - val_loss: 504.5044 - learning_rate: 4.4847e-04
# Epoch 80/200
# 16/16 - 0s - 18ms/step - loss: 350.6163 - val_loss: 495.2494 - learning_rate: 4.4847e-04
# Epoch 81/200
# 16/16 - 0s - 24ms/step - loss: 353.2187 - val_loss: 480.1205 - learning_rate: 4.4847e-04
# Epoch 82/200
# 16/16 - 1s - 39ms/step - loss: 332.2748 - val_loss: 469.3758 - learning_rate: 4.4847e-04
# Epoch 83/200
# 16/16 - 0s - 26ms/step - loss: 311.4353 - val_loss: 467.6699 - learning_rate: 4.4847e-04
# Epoch 84/200
# 16/16 - 0s - 21ms/step - loss: 307.7386 - val_loss: 456.5702 - learning_rate: 4.4847e-04
# Epoch 85/200
# 16/16 - 0s - 23ms/step - loss: 303.9586 - val_loss: 447.8455 - learning_rate: 4.4847e-04
# Epoch 86/200
# 16/16 - 0s - 20ms/step - loss: 306.8073 - val_loss: 441.0760 - learning_rate: 4.4847e-04
# Epoch 87/200
# 16/16 - 0s - 16ms/step - loss: 275.5960 - val_loss: 432.7595 - learning_rate: 4.4847e-04
# Epoch 88/200
# 16/16 - 0s - 24ms/step - loss: 269.3002 - val_loss: 429.4215 - learning_rate: 4.4847e-04
# Epoch 89/200
# 16/16 - 0s - 20ms/step - loss: 281.9673 - val_loss: 430.4019 - learning_rate: 4.4847e-04
# Epoch 90/200
# 16/16 - 0s - 18ms/step - loss: 266.8440 - val_loss: 430.0603 - learning_rate: 4.4847e-04
# Epoch 91/200
# 16/16 - 0s - 21ms/step - loss: 258.6773 - val_loss: 424.9714 - learning_rate: 4.4847e-04
# Epoch 92/200
# 16/16 - 0s - 22ms/step - loss: 222.6364 - val_loss: 422.9064 - learning_rate: 4.4847e-04
# Epoch 93/200
# 16/16 - 0s - 17ms/step - loss: 252.0414 - val_loss: 417.8198 - learning_rate: 4.4847e-04
# Epoch 94/200
# 16/16 - 0s - 22ms/step - loss: 249.4424 - val_loss: 416.2557 - learning_rate: 4.4847e-04
# Epoch 95/200
# 16/16 - 0s - 20ms/step - loss: 250.9856 - val_loss: 411.2876 - learning_rate: 4.4847e-04
# Epoch 96/200
# 16/16 - 0s - 22ms/step - loss: 234.5139 - val_loss: 408.6400 - learning_rate: 4.4847e-04
# Epoch 97/200
# 16/16 - 0s - 20ms/step - loss: 244.0197 - val_loss: 407.6584 - learning_rate: 4.4847e-04
# Epoch 98/200
# 16/16 - 0s - 18ms/step - loss: 231.0903 - val_loss: 408.0173 - learning_rate: 4.4847e-04
# Epoch 99/200
# 16/16 - 0s - 16ms/step - loss: 230.1754 - val_loss: 406.6396 - learning_rate: 4.4847e-04
# Epoch 100/200
# 16/16 - 0s - 17ms/step - loss: 224.4210 - val_loss: 405.5882 - learning_rate: 4.4847e-04
# Epoch 101/200
# 16/16 - 0s - 21ms/step - loss: 223.6492 - val_loss: 406.1392 - learning_rate: 4.4847e-04
# Epoch 102/200
# 16/16 - 0s - 20ms/step - loss: 211.0286 - val_loss: 405.7746 - learning_rate: 4.4847e-04
# Epoch 103/200
# 16/16 - 0s - 17ms/step - loss: 251.4509 - val_loss: 407.2997 - learning_rate: 4.4847e-04
# Epoch 104/200
# 16/16 - 0s - 21ms/step - loss: 227.4569 - val_loss: 407.9718 - learning_rate: 4.4847e-04
# Epoch 105/200
# 16/16 - 0s - 20ms/step - loss: 217.8058 - val_loss: 405.7895 - learning_rate: 4.4847e-04
# Epoch 106/200
# 16/16 - 0s - 18ms/step - loss: 217.8812 - val_loss: 405.4811 - learning_rate: 2.2423e-04
# Epoch 107/200
# 16/16 - 0s - 22ms/step - loss: 231.6402 - val_loss: 404.8958 - learning_rate: 2.2423e-04
# Epoch 108/200
# 16/16 - 0s - 17ms/step - loss: 213.2705 - val_loss: 405.2969 - learning_rate: 2.2423e-04
# Epoch 109/200
# 16/16 - 0s - 18ms/step - loss: 237.5418 - val_loss: 400.6525 - learning_rate: 2.2423e-04
# Epoch 110/200
# 16/16 - 0s - 22ms/step - loss: 226.8855 - val_loss: 401.8950 - learning_rate: 2.2423e-04
# Epoch 111/200
# 16/16 - 0s - 18ms/step - loss: 222.6902 - val_loss: 400.9128 - learning_rate: 2.2423e-04
# Epoch 112/200
# 16/16 - 0s - 22ms/step - loss: 218.4833 - val_loss: 401.3876 - learning_rate: 2.2423e-04
# Epoch 113/200
# 16/16 - 0s - 20ms/step - loss: 211.4926 - val_loss: 401.9036 - learning_rate: 2.2423e-04
# Epoch 114/200
# 16/16 - 0s - 23ms/step - loss: 232.7536 - val_loss: 401.5570 - learning_rate: 2.2423e-04
# Epoch 115/200
# 16/16 - 0s - 21ms/step - loss: 217.0389 - val_loss: 402.0428 - learning_rate: 1.1212e-04
# Epoch 116/200
# 16/16 - 0s - 20ms/step - loss: 219.8262 - val_loss: 402.9991 - learning_rate: 1.1212e-04
# Epoch 117/200
# 16/16 - 0s - 21ms/step - loss: 206.4650 - val_loss: 402.8482 - learning_rate: 1.1212e-04
# Epoch 118/200
# 16/16 - 0s - 21ms/step - loss: 209.4893 - val_loss: 401.8924 - learning_rate: 1.1212e-04
# Epoch 119/200
# 16/16 - 0s - 19ms/step - loss: 217.0824 - val_loss: 401.4847 - learning_rate: 1.1212e-04
# Epoch 120/200
# 16/16 - 0s - 19ms/step - loss: 200.7422 - val_loss: 401.4799 - learning_rate: 5.6058e-05
# Epoch 121/200
# 16/16 - 0s - 20ms/step - loss: 227.8880 - val_loss: 401.9102 - learning_rate: 5.6058e-05
# Epoch 122/200
# 16/16 - 0s - 21ms/step - loss: 214.5337 - val_loss: 402.4148 - learning_rate: 5.6058e-05
# Epoch 123/200
# 16/16 - 0s - 21ms/step - loss: 218.5061 - val_loss: 402.4117 - learning_rate: 5.6058e-05
# Epoch 124/200
# 16/16 - 0s - 22ms/step - loss: 227.5931 - val_loss: 402.0011 - learning_rate: 5.6058e-05
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Epoch 1/200
# 16/16 - 3s - 173ms/step - loss: 4147.5410 - val_loss: 3905.4861 - learning_rate: 4.4847e-04
# Epoch 2/200
# 16/16 - 0s - 22ms/step - loss: 4102.5898 - val_loss: 3884.1328 - learning_rate: 4.4847e-04
# Epoch 3/200
# 16/16 - 0s - 21ms/step - loss: 4071.9822 - val_loss: 3861.3674 - learning_rate: 4.4847e-04
# Epoch 4/200
# 16/16 - 0s - 21ms/step - loss: 4045.2253 - val_loss: 3838.6423 - learning_rate: 4.4847e-04
# Epoch 5/200
# 16/16 - 0s - 21ms/step - loss: 4008.5764 - val_loss: 3814.6484 - learning_rate: 4.4847e-04
# Epoch 6/200
# 16/16 - 0s - 19ms/step - loss: 3985.4543 - val_loss: 3788.9314 - learning_rate: 4.4847e-04
# Epoch 7/200
# 16/16 - 0s - 17ms/step - loss: 3945.1873 - val_loss: 3760.5356 - learning_rate: 4.4847e-04
# Epoch 8/200
# 16/16 - 0s - 20ms/step - loss: 3910.5435 - val_loss: 3730.5581 - learning_rate: 4.4847e-04
# Epoch 9/200
# 16/16 - 0s - 21ms/step - loss: 3880.1624 - val_loss: 3698.6006 - learning_rate: 4.4847e-04
# Epoch 10/200
# 16/16 - 0s - 21ms/step - loss: 3850.2754 - val_loss: 3664.8088 - learning_rate: 4.4847e-04
# Epoch 11/200
# 16/16 - 0s - 19ms/step - loss: 3810.6177 - val_loss: 3628.2830 - learning_rate: 4.4847e-04
# Epoch 12/200
# 16/16 - 0s - 22ms/step - loss: 3771.5740 - val_loss: 3591.3486 - learning_rate: 4.4847e-04
# Epoch 13/200
# 16/16 - 0s - 20ms/step - loss: 3730.9119 - val_loss: 3550.3804 - learning_rate: 4.4847e-04
# Epoch 14/200
# 16/16 - 0s - 21ms/step - loss: 3702.9009 - val_loss: 3509.8311 - learning_rate: 4.4847e-04
# Epoch 15/200
# 16/16 - 0s - 20ms/step - loss: 3656.5642 - val_loss: 3467.7979 - learning_rate: 4.4847e-04
# Epoch 16/200
# 16/16 - 0s - 21ms/step - loss: 3620.2927 - val_loss: 3425.5408 - learning_rate: 4.4847e-04
# Epoch 17/200
# 16/16 - 0s - 20ms/step - loss: 3578.1941 - val_loss: 3383.3025 - learning_rate: 4.4847e-04
# Epoch 18/200
# 16/16 - 0s - 20ms/step - loss: 3545.1917 - val_loss: 3334.9312 - learning_rate: 4.4847e-04
# Epoch 19/200
# 16/16 - 0s - 21ms/step - loss: 3488.5457 - val_loss: 3292.8293 - learning_rate: 4.4847e-04
# Epoch 20/200
# 16/16 - 0s - 20ms/step - loss: 3471.8599 - val_loss: 3246.8252 - learning_rate: 4.4847e-04
# Epoch 21/200
# 16/16 - 0s - 21ms/step - loss: 3401.8745 - val_loss: 3193.9470 - learning_rate: 4.4847e-04
# Epoch 22/200
# 16/16 - 0s - 20ms/step - loss: 3363.3035 - val_loss: 3143.4717 - learning_rate: 4.4847e-04
# Epoch 23/200
# 16/16 - 0s - 18ms/step - loss: 3298.7546 - val_loss: 3088.0322 - learning_rate: 4.4847e-04
# Epoch 24/200
# 16/16 - 0s - 21ms/step - loss: 3246.2083 - val_loss: 3043.7383 - learning_rate: 4.4847e-04
# Epoch 25/200
# 16/16 - 0s - 21ms/step - loss: 3211.5042 - val_loss: 2993.3767 - learning_rate: 4.4847e-04
# Epoch 26/200
# 16/16 - 0s - 18ms/step - loss: 3151.2346 - val_loss: 2941.2063 - learning_rate: 4.4847e-04
# Epoch 27/200
# 16/16 - 0s - 19ms/step - loss: 3105.3804 - val_loss: 2891.6892 - learning_rate: 4.4847e-04
# Epoch 28/200
# 16/16 - 0s - 20ms/step - loss: 3050.3315 - val_loss: 2838.9126 - learning_rate: 4.4847e-04
# Epoch 29/200
# 16/16 - 0s - 23ms/step - loss: 2966.1514 - val_loss: 2778.8887 - learning_rate: 4.4847e-04
# Epoch 30/200
# 16/16 - 0s - 19ms/step - loss: 2915.5889 - val_loss: 2728.0833 - learning_rate: 4.4847e-04
# Epoch 31/200
# 16/16 - 0s - 18ms/step - loss: 2859.7002 - val_loss: 2672.7083 - learning_rate: 4.4847e-04
# Epoch 32/200
# 16/16 - 0s - 21ms/step - loss: 2807.1240 - val_loss: 2611.0913 - learning_rate: 4.4847e-04
# Epoch 33/200
# 16/16 - 0s - 18ms/step - loss: 2727.1733 - val_loss: 2553.2278 - learning_rate: 4.4847e-04
# Epoch 34/200
# 16/16 - 0s - 20ms/step - loss: 2686.7053 - val_loss: 2490.1494 - learning_rate: 4.4847e-04
# Epoch 35/200
# 16/16 - 0s - 18ms/step - loss: 2577.0706 - val_loss: 2425.1616 - learning_rate: 4.4847e-04
# Epoch 36/200
# 16/16 - 0s - 21ms/step - loss: 2506.2852 - val_loss: 2362.1956 - learning_rate: 4.4847e-04
# Epoch 37/200
# 16/16 - 0s - 23ms/step - loss: 2432.3088 - val_loss: 2295.5264 - learning_rate: 4.4847e-04
# Epoch 38/200
# 16/16 - 0s - 20ms/step - loss: 2384.0667 - val_loss: 2235.2224 - learning_rate: 4.4847e-04
# Epoch 39/200
# 16/16 - 0s - 21ms/step - loss: 2305.9915 - val_loss: 2163.4451 - learning_rate: 4.4847e-04
# Epoch 40/200
# 16/16 - 0s - 21ms/step - loss: 2217.8169 - val_loss: 2089.5940 - learning_rate: 4.4847e-04
# Epoch 41/200
# 16/16 - 0s - 21ms/step - loss: 2168.3250 - val_loss: 2019.9998 - learning_rate: 4.4847e-04
# Epoch 42/200
# 16/16 - 0s - 19ms/step - loss: 2090.9758 - val_loss: 1958.0728 - learning_rate: 4.4847e-04
# Epoch 43/200
# 16/16 - 0s - 19ms/step - loss: 2006.6196 - val_loss: 1894.3094 - learning_rate: 4.4847e-04
# Epoch 44/200
# 16/16 - 0s - 20ms/step - loss: 1945.2627 - val_loss: 1826.3647 - learning_rate: 4.4847e-04
# Epoch 45/200
# 16/16 - 0s - 18ms/step - loss: 1866.0433 - val_loss: 1760.2947 - learning_rate: 4.4847e-04
# Epoch 46/200
# 16/16 - 0s - 23ms/step - loss: 1792.6357 - val_loss: 1694.5149 - learning_rate: 4.4847e-04
# Epoch 47/200
# 16/16 - 0s - 21ms/step - loss: 1729.2474 - val_loss: 1629.6338 - learning_rate: 4.4847e-04
# Epoch 48/200
# 16/16 - 0s - 23ms/step - loss: 1649.6401 - val_loss: 1562.7726 - learning_rate: 4.4847e-04
# Epoch 49/200
# 16/16 - 0s - 18ms/step - loss: 1601.3824 - val_loss: 1492.9657 - learning_rate: 4.4847e-04
# Epoch 50/200
# 16/16 - 0s - 19ms/step - loss: 1530.4880 - val_loss: 1427.8964 - learning_rate: 4.4847e-04
# Epoch 51/200
# 16/16 - 0s - 22ms/step - loss: 1464.2698 - val_loss: 1363.0179 - learning_rate: 4.4847e-04
# Epoch 52/200
# 16/16 - 0s - 18ms/step - loss: 1394.9368 - val_loss: 1309.6710 - learning_rate: 4.4847e-04
# Epoch 53/200
# 16/16 - 0s - 19ms/step - loss: 1331.7397 - val_loss: 1256.6849 - learning_rate: 4.4847e-04
# Epoch 54/200
# 16/16 - 0s - 21ms/step - loss: 1231.9054 - val_loss: 1199.4216 - learning_rate: 4.4847e-04
# Epoch 55/200
# 16/16 - 0s - 22ms/step - loss: 1232.3215 - val_loss: 1141.7837 - learning_rate: 4.4847e-04
# Epoch 56/200
# 16/16 - 0s - 21ms/step - loss: 1135.5454 - val_loss: 1092.8108 - learning_rate: 4.4847e-04
# Epoch 57/200
# 16/16 - 0s - 20ms/step - loss: 1076.2491 - val_loss: 1039.5244 - learning_rate: 4.4847e-04
# Epoch 58/200
# 16/16 - 0s - 21ms/step - loss: 1019.5712 - val_loss: 991.3439 - learning_rate: 4.4847e-04
# Epoch 59/200
# 16/16 - 0s - 20ms/step - loss: 985.1187 - val_loss: 947.9642 - learning_rate: 4.4847e-04
# Epoch 60/200
# 16/16 - 0s - 20ms/step - loss: 921.1506 - val_loss: 902.7410 - learning_rate: 4.4847e-04
# Epoch 61/200
# 16/16 - 0s - 21ms/step - loss: 857.3056 - val_loss: 855.9013 - learning_rate: 4.4847e-04
# Epoch 62/200
# 16/16 - 0s - 22ms/step - loss: 831.1280 - val_loss: 809.7500 - learning_rate: 4.4847e-04
# Epoch 63/200
# 16/16 - 0s - 20ms/step - loss: 789.4057 - val_loss: 775.5284 - learning_rate: 4.4847e-04
# Epoch 64/200
# 16/16 - 0s - 20ms/step - loss: 740.6937 - val_loss: 739.0740 - learning_rate: 4.4847e-04
# Epoch 65/200
# 16/16 - 0s - 21ms/step - loss: 697.8591 - val_loss: 706.2110 - learning_rate: 4.4847e-04
# Epoch 66/200
# 16/16 - 0s - 20ms/step - loss: 679.9695 - val_loss: 677.0109 - learning_rate: 4.4847e-04
# Epoch 67/200
# 16/16 - 0s - 21ms/step - loss: 625.9938 - val_loss: 642.9904 - learning_rate: 4.4847e-04
# Epoch 68/200
# 16/16 - 0s - 21ms/step - loss: 603.8513 - val_loss: 615.4373 - learning_rate: 4.4847e-04
# Epoch 69/200
# 16/16 - 0s - 18ms/step - loss: 557.8250 - val_loss: 588.6357 - learning_rate: 4.4847e-04
# Epoch 70/200
# 16/16 - 0s - 20ms/step - loss: 539.0270 - val_loss: 558.4817 - learning_rate: 4.4847e-04
# Epoch 71/200
# 16/16 - 0s - 16ms/step - loss: 506.2547 - val_loss: 536.3110 - learning_rate: 4.4847e-04
# Epoch 72/200
# 16/16 - 0s - 17ms/step - loss: 498.0751 - val_loss: 517.9704 - learning_rate: 4.4847e-04
# Epoch 73/200
# 16/16 - 0s - 20ms/step - loss: 449.3806 - val_loss: 498.4747 - learning_rate: 4.4847e-04
# Epoch 74/200
# 16/16 - 0s - 21ms/step - loss: 439.1588 - val_loss: 479.1819 - learning_rate: 4.4847e-04
# Epoch 75/200
# 16/16 - 0s - 17ms/step - loss: 397.0322 - val_loss: 463.3745 - learning_rate: 4.4847e-04
# Epoch 76/200
# 16/16 - 0s - 22ms/step - loss: 387.9307 - val_loss: 444.3704 - learning_rate: 4.4847e-04
# Epoch 77/200
# 16/16 - 0s - 20ms/step - loss: 387.8713 - val_loss: 430.3915 - learning_rate: 4.4847e-04
# Epoch 78/200
# 16/16 - 0s - 18ms/step - loss: 358.6947 - val_loss: 417.3280 - learning_rate: 4.4847e-04
# Epoch 79/200
# 16/16 - 0s - 18ms/step - loss: 342.5199 - val_loss: 406.0434 - learning_rate: 4.4847e-04
# Epoch 80/200
# 16/16 - 0s - 20ms/step - loss: 321.3999 - val_loss: 395.5616 - learning_rate: 4.4847e-04
# Epoch 81/200
# 16/16 - 0s - 19ms/step - loss: 326.8166 - val_loss: 386.1307 - learning_rate: 4.4847e-04
# Epoch 82/200
# 16/16 - 0s - 17ms/step - loss: 315.0381 - val_loss: 377.8375 - learning_rate: 4.4847e-04
# Epoch 83/200
# 16/16 - 0s - 19ms/step - loss: 288.0446 - val_loss: 367.8720 - learning_rate: 4.4847e-04
# Epoch 84/200
# 16/16 - 0s - 17ms/step - loss: 299.0960 - val_loss: 363.0699 - learning_rate: 4.4847e-04
# Epoch 85/200
# 16/16 - 0s - 15ms/step - loss: 297.7881 - val_loss: 364.0862 - learning_rate: 4.4847e-04
# Epoch 86/200
# 16/16 - 0s - 24ms/step - loss: 271.3922 - val_loss: 356.1393 - learning_rate: 4.4847e-04
# Epoch 87/200
# 16/16 - 0s - 20ms/step - loss: 256.6928 - val_loss: 352.0346 - learning_rate: 4.4847e-04
# Epoch 88/200
# 16/16 - 0s - 16ms/step - loss: 274.1019 - val_loss: 348.7816 - learning_rate: 4.4847e-04
# Epoch 89/200
# 16/16 - 0s - 21ms/step - loss: 263.2931 - val_loss: 345.3474 - learning_rate: 4.4847e-04
# Epoch 90/200
# 16/16 - 0s - 21ms/step - loss: 250.0764 - val_loss: 343.0180 - learning_rate: 4.4847e-04
# Epoch 91/200
# 16/16 - 0s - 21ms/step - loss: 254.3527 - val_loss: 342.0764 - learning_rate: 4.4847e-04
# Epoch 92/200
# 16/16 - 0s - 21ms/step - loss: 236.2495 - val_loss: 339.2611 - learning_rate: 4.4847e-04
# Epoch 93/200
# 16/16 - 0s - 20ms/step - loss: 239.2236 - val_loss: 334.3788 - learning_rate: 4.4847e-04
# Epoch 94/200
# 16/16 - 0s - 22ms/step - loss: 240.2849 - val_loss: 333.1628 - learning_rate: 4.4847e-04
# Epoch 95/200
# 16/16 - 0s - 21ms/step - loss: 221.2341 - val_loss: 331.7159 - learning_rate: 4.4847e-04
# Epoch 96/200
# 16/16 - 0s - 21ms/step - loss: 226.7558 - val_loss: 330.8369 - learning_rate: 4.4847e-04
# Epoch 97/200
# 16/16 - 0s - 20ms/step - loss: 210.0252 - val_loss: 332.7365 - learning_rate: 4.4847e-04
# Epoch 98/200
# 16/16 - 0s - 21ms/step - loss: 220.8306 - val_loss: 329.8183 - learning_rate: 4.4847e-04
# Epoch 99/200
# 16/16 - 0s - 19ms/step - loss: 219.9057 - val_loss: 334.7432 - learning_rate: 4.4847e-04
# Epoch 100/200
# 16/16 - 0s - 21ms/step - loss: 211.5157 - val_loss: 331.6803 - learning_rate: 4.4847e-04
# Epoch 101/200
# 16/16 - 0s - 17ms/step - loss: 217.5819 - val_loss: 333.8551 - learning_rate: 4.4847e-04
# Epoch 102/200
# 16/16 - 0s - 20ms/step - loss: 216.6148 - val_loss: 331.1598 - learning_rate: 4.4847e-04
# Epoch 103/200
# 16/16 - 0s - 17ms/step - loss: 221.1253 - val_loss: 331.7588 - learning_rate: 4.4847e-04
# Epoch 104/200
# 16/16 - 0s - 17ms/step - loss: 216.5752 - val_loss: 331.6485 - learning_rate: 2.2423e-04
# Epoch 105/200
# 16/16 - 0s - 17ms/step - loss: 203.4816 - val_loss: 331.6630 - learning_rate: 2.2423e-04
# Epoch 106/200
# 16/16 - 0s - 19ms/step - loss: 217.5040 - val_loss: 332.6013 - learning_rate: 2.2423e-04
# Epoch 107/200
# 16/16 - 0s - 20ms/step - loss: 216.2509 - val_loss: 331.9017 - learning_rate: 2.2423e-04
# Epoch 108/200
# 16/16 - 0s - 18ms/step - loss: 198.8426 - val_loss: 332.4605 - learning_rate: 2.2423e-04
# Epoch 109/200
# 16/16 - 0s - 17ms/step - loss: 208.8890 - val_loss: 333.0623 - learning_rate: 1.1212e-04
# Epoch 110/200
# 16/16 - 0s - 24ms/step - loss: 225.2140 - val_loss: 334.1462 - learning_rate: 1.1212e-04
# Epoch 111/200
# 16/16 - 0s - 20ms/step - loss: 209.4334 - val_loss: 334.9857 - learning_rate: 1.1212e-04
# Epoch 112/200
# 16/16 - 0s - 21ms/step - loss: 198.5354 - val_loss: 334.9418 - learning_rate: 1.1212e-04
# Epoch 113/200
# 16/16 - 0s - 17ms/step - loss: 206.9460 - val_loss: 336.1940 - learning_rate: 1.1212e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 1/200
# 16/16 - 3s - 172ms/step - loss: 4165.6963 - val_loss: 3923.1072 - learning_rate: 4.4847e-04
# Epoch 2/200
# 16/16 - 0s - 17ms/step - loss: 4129.4785 - val_loss: 3904.1499 - learning_rate: 4.4847e-04
# Epoch 3/200
# 16/16 - 0s - 20ms/step - loss: 4082.5601 - val_loss: 3884.0293 - learning_rate: 4.4847e-04
# Epoch 4/200
# 16/16 - 0s - 17ms/step - loss: 4053.0127 - val_loss: 3863.2949 - learning_rate: 4.4847e-04
# Epoch 5/200
# 16/16 - 0s - 20ms/step - loss: 4014.6931 - val_loss: 3841.0701 - learning_rate: 4.4847e-04
# Epoch 6/200
# 16/16 - 0s - 21ms/step - loss: 3980.1025 - val_loss: 3816.3059 - learning_rate: 4.4847e-04
# Epoch 7/200
# 16/16 - 0s - 21ms/step - loss: 3938.8765 - val_loss: 3789.3008 - learning_rate: 4.4847e-04
# Epoch 8/200
# 16/16 - 0s - 20ms/step - loss: 3917.5286 - val_loss: 3758.4670 - learning_rate: 4.4847e-04
# Epoch 9/200
# 16/16 - 0s - 21ms/step - loss: 3878.6931 - val_loss: 3727.3909 - learning_rate: 4.4847e-04
# Epoch 10/200
# 16/16 - 0s - 23ms/step - loss: 3853.9563 - val_loss: 3692.2778 - learning_rate: 4.4847e-04
# Epoch 11/200
# 16/16 - 0s - 17ms/step - loss: 3821.4121 - val_loss: 3656.2620 - learning_rate: 4.4847e-04
# Epoch 12/200
# 16/16 - 0s - 14ms/step - loss: 3776.8538 - val_loss: 3618.7039 - learning_rate: 4.4847e-04
# Epoch 13/200
# 16/16 - 0s - 22ms/step - loss: 3745.4387 - val_loss: 3575.4060 - learning_rate: 4.4847e-04
# Epoch 14/200
# 16/16 - 0s - 17ms/step - loss: 3701.9294 - val_loss: 3529.9514 - learning_rate: 4.4847e-04
# Epoch 15/200
# 16/16 - 0s - 21ms/step - loss: 3658.3755 - val_loss: 3481.6462 - learning_rate: 4.4847e-04
# Epoch 16/200
# 16/16 - 0s - 16ms/step - loss: 3621.0076 - val_loss: 3431.7637 - learning_rate: 4.4847e-04
# Epoch 17/200
# 16/16 - 0s - 16ms/step - loss: 3586.7092 - val_loss: 3386.5942 - learning_rate: 4.4847e-04
# Epoch 18/200
# 16/16 - 0s - 21ms/step - loss: 3533.5229 - val_loss: 3335.6416 - learning_rate: 4.4847e-04
# Epoch 19/200
# 16/16 - 0s - 20ms/step - loss: 3489.3257 - val_loss: 3285.6562 - learning_rate: 4.4847e-04
# Epoch 20/200
# 16/16 - 0s - 17ms/step - loss: 3441.9768 - val_loss: 3231.9353 - learning_rate: 4.4847e-04
# Epoch 21/200
# 16/16 - 0s - 19ms/step - loss: 3407.4419 - val_loss: 3178.2173 - learning_rate: 4.4847e-04
# Epoch 22/200
# 16/16 - 0s - 19ms/step - loss: 3362.0574 - val_loss: 3125.5911 - learning_rate: 4.4847e-04
# Epoch 23/200
# 16/16 - 0s - 17ms/step - loss: 3296.9023 - val_loss: 3071.1331 - learning_rate: 4.4847e-04
# Epoch 24/200
# 16/16 - 0s - 18ms/step - loss: 3237.5903 - val_loss: 3020.9961 - learning_rate: 4.4847e-04
# Epoch 25/200
# 16/16 - 0s - 16ms/step - loss: 3190.5120 - val_loss: 2964.4868 - learning_rate: 4.4847e-04
# Epoch 26/200
# 16/16 - 0s - 16ms/step - loss: 3121.1060 - val_loss: 2908.4456 - learning_rate: 4.4847e-04
# Epoch 27/200
# 16/16 - 0s - 23ms/step - loss: 3090.0779 - val_loss: 2855.4573 - learning_rate: 4.4847e-04
# Epoch 28/200
# 16/16 - 0s - 16ms/step - loss: 3016.9526 - val_loss: 2796.9526 - learning_rate: 4.4847e-04
# Epoch 29/200
# 16/16 - 0s - 17ms/step - loss: 2970.9827 - val_loss: 2735.0017 - learning_rate: 4.4847e-04
# Epoch 30/200
# 16/16 - 0s - 21ms/step - loss: 2907.9817 - val_loss: 2681.0586 - learning_rate: 4.4847e-04
# Epoch 31/200
# 16/16 - 0s - 17ms/step - loss: 2849.8965 - val_loss: 2623.1040 - learning_rate: 4.4847e-04
# Epoch 32/200
# 16/16 - 0s - 16ms/step - loss: 2771.7083 - val_loss: 2564.4653 - learning_rate: 4.4847e-04
# Epoch 33/200
# 16/16 - 0s - 21ms/step - loss: 2738.9634 - val_loss: 2499.3579 - learning_rate: 4.4847e-04
# Epoch 34/200
# 16/16 - 0s - 16ms/step - loss: 2656.4802 - val_loss: 2443.1667 - learning_rate: 4.4847e-04
# Epoch 35/200
# 16/16 - 0s - 21ms/step - loss: 2589.7732 - val_loss: 2387.4248 - learning_rate: 4.4847e-04
# Epoch 36/200
# 16/16 - 0s - 20ms/step - loss: 2526.4102 - val_loss: 2329.9741 - learning_rate: 4.4847e-04
# Epoch 37/200
# 16/16 - 0s - 16ms/step - loss: 2455.7283 - val_loss: 2263.8203 - learning_rate: 4.4847e-04
# Epoch 38/200
# 16/16 - 0s - 17ms/step - loss: 2369.4434 - val_loss: 2201.5276 - learning_rate: 4.4847e-04
# Epoch 39/200
# 16/16 - 0s - 18ms/step - loss: 2298.3848 - val_loss: 2129.7566 - learning_rate: 4.4847e-04
# Epoch 40/200
# 16/16 - 0s - 23ms/step - loss: 2238.7563 - val_loss: 2068.6389 - learning_rate: 4.4847e-04
# Epoch 41/200
# 16/16 - 0s - 16ms/step - loss: 2158.1558 - val_loss: 2007.2561 - learning_rate: 4.4847e-04
# Epoch 42/200
# 16/16 - 0s - 20ms/step - loss: 2072.7869 - val_loss: 1936.8207 - learning_rate: 4.4847e-04
# Epoch 43/200
# 16/16 - 0s - 20ms/step - loss: 1992.2717 - val_loss: 1872.0521 - learning_rate: 4.4847e-04
# Epoch 44/200
# 16/16 - 0s - 19ms/step - loss: 1929.7300 - val_loss: 1806.1445 - learning_rate: 4.4847e-04
# Epoch 45/200
# 16/16 - 0s - 17ms/step - loss: 1867.8408 - val_loss: 1745.1952 - learning_rate: 4.4847e-04
# Epoch 46/200
# 16/16 - 0s - 21ms/step - loss: 1778.4375 - val_loss: 1685.6417 - learning_rate: 4.4847e-04
# Epoch 47/200
# 16/16 - 0s - 17ms/step - loss: 1724.1061 - val_loss: 1619.6315 - learning_rate: 4.4847e-04
# Epoch 48/200
# 16/16 - 0s - 20ms/step - loss: 1653.0327 - val_loss: 1559.0668 - learning_rate: 4.4847e-04
# Epoch 49/200
# 16/16 - 0s - 22ms/step - loss: 1590.5287 - val_loss: 1491.0315 - learning_rate: 4.4847e-04
# Epoch 50/200
# 16/16 - 0s - 22ms/step - loss: 1516.9388 - val_loss: 1431.1572 - learning_rate: 4.4847e-04
# Epoch 51/200
# 16/16 - 0s - 20ms/step - loss: 1448.8503 - val_loss: 1371.5770 - learning_rate: 4.4847e-04
# Epoch 52/200
# 16/16 - 0s - 22ms/step - loss: 1373.8740 - val_loss: 1322.3947 - learning_rate: 4.4847e-04
# Epoch 53/200
# 16/16 - 0s - 19ms/step - loss: 1342.0341 - val_loss: 1266.3608 - learning_rate: 4.4847e-04
# Epoch 54/200
# 16/16 - 0s - 21ms/step - loss: 1279.2944 - val_loss: 1211.2988 - learning_rate: 4.4847e-04
# Epoch 55/200
# 16/16 - 0s - 19ms/step - loss: 1212.7223 - val_loss: 1161.5841 - learning_rate: 4.4847e-04
# Epoch 56/200
# 16/16 - 0s - 16ms/step - loss: 1140.6095 - val_loss: 1108.2433 - learning_rate: 4.4847e-04
# Epoch 57/200
# 16/16 - 0s - 22ms/step - loss: 1072.5924 - val_loss: 1058.8060 - learning_rate: 4.4847e-04
# Epoch 58/200
# 16/16 - 0s - 17ms/step - loss: 1030.1091 - val_loss: 1009.3748 - learning_rate: 4.4847e-04
# Epoch 59/200
# 16/16 - 0s - 20ms/step - loss: 960.4388 - val_loss: 964.7291 - learning_rate: 4.4847e-04
# Epoch 60/200
# 16/16 - 0s - 20ms/step - loss: 939.4553 - val_loss: 923.2051 - learning_rate: 4.4847e-04
# Epoch 61/200
# 16/16 - 0s - 19ms/step - loss: 886.3165 - val_loss: 886.5469 - learning_rate: 4.4847e-04
# Epoch 62/200
# 16/16 - 0s - 20ms/step - loss: 855.4877 - val_loss: 847.8879 - learning_rate: 4.4847e-04
# Epoch 63/200
# 16/16 - 0s - 18ms/step - loss: 795.5828 - val_loss: 807.9865 - learning_rate: 4.4847e-04
# Epoch 64/200
# 16/16 - 0s - 17ms/step - loss: 747.2348 - val_loss: 774.3881 - learning_rate: 4.4847e-04
# Epoch 65/200
# 16/16 - 0s - 20ms/step - loss: 700.7593 - val_loss: 737.7830 - learning_rate: 4.4847e-04
# Epoch 66/200
# 16/16 - 0s - 21ms/step - loss: 672.5878 - val_loss: 711.9589 - learning_rate: 4.4847e-04
# Epoch 67/200
# 16/16 - 0s - 19ms/step - loss: 658.6782 - val_loss: 684.7927 - learning_rate: 4.4847e-04
# Epoch 68/200
# 16/16 - 0s - 19ms/step - loss: 611.5899 - val_loss: 657.0443 - learning_rate: 4.4847e-04
# Epoch 69/200
# 16/16 - 0s - 18ms/step - loss: 575.2614 - val_loss: 625.8578 - learning_rate: 4.4847e-04
# Epoch 70/200
# 16/16 - 0s - 16ms/step - loss: 534.0829 - val_loss: 603.0904 - learning_rate: 4.4847e-04
# Epoch 71/200
# 16/16 - 0s - 21ms/step - loss: 517.3505 - val_loss: 580.3436 - learning_rate: 4.4847e-04
# Epoch 72/200
# 16/16 - 0s - 21ms/step - loss: 479.3991 - val_loss: 564.8734 - learning_rate: 4.4847e-04
# Epoch 73/200
# 16/16 - 0s - 21ms/step - loss: 477.1336 - val_loss: 545.1141 - learning_rate: 4.4847e-04
# Epoch 74/200
# 16/16 - 0s - 17ms/step - loss: 455.6709 - val_loss: 530.0231 - learning_rate: 4.4847e-04
# Epoch 75/200
# 16/16 - 0s - 21ms/step - loss: 420.6884 - val_loss: 514.0523 - learning_rate: 4.4847e-04
# Epoch 76/200
# 16/16 - 0s - 19ms/step - loss: 409.3485 - val_loss: 504.2693 - learning_rate: 4.4847e-04
# Epoch 77/200
# 16/16 - 0s - 22ms/step - loss: 372.6382 - val_loss: 487.3033 - learning_rate: 4.4847e-04
# Epoch 78/200
# 16/16 - 0s - 22ms/step - loss: 375.6405 - val_loss: 473.5468 - learning_rate: 4.4847e-04
# Epoch 79/200
# 16/16 - 0s - 22ms/step - loss: 361.8035 - val_loss: 464.8608 - learning_rate: 4.4847e-04
# Epoch 80/200
# 16/16 - 0s - 18ms/step - loss: 320.0603 - val_loss: 459.2055 - learning_rate: 4.4847e-04
# Epoch 81/200
# 16/16 - 0s - 16ms/step - loss: 333.1660 - val_loss: 447.4730 - learning_rate: 4.4847e-04
# Epoch 82/200
# 16/16 - 0s - 17ms/step - loss: 311.9342 - val_loss: 442.5748 - learning_rate: 4.4847e-04
# Epoch 83/200
# 16/16 - 0s - 18ms/step - loss: 306.3904 - val_loss: 435.3470 - learning_rate: 4.4847e-04
# Epoch 84/200
# 16/16 - 0s - 19ms/step - loss: 305.8047 - val_loss: 429.1029 - learning_rate: 4.4847e-04
# Epoch 85/200
# 16/16 - 0s - 16ms/step - loss: 291.0490 - val_loss: 427.7390 - learning_rate: 4.4847e-04
# Epoch 86/200
# 16/16 - 0s - 20ms/step - loss: 282.2096 - val_loss: 423.4061 - learning_rate: 4.4847e-04
# Epoch 87/200
# 16/16 - 0s - 21ms/step - loss: 281.5609 - val_loss: 420.3553 - learning_rate: 4.4847e-04
# Epoch 88/200
# 16/16 - 0s - 17ms/step - loss: 255.3587 - val_loss: 418.0878 - learning_rate: 4.4847e-04
# Epoch 89/200
# 16/16 - 0s - 17ms/step - loss: 269.2073 - val_loss: 416.8436 - learning_rate: 4.4847e-04
# Epoch 90/200
# 16/16 - 0s - 21ms/step - loss: 253.0158 - val_loss: 411.0274 - learning_rate: 4.4847e-04
# Epoch 91/200
# 16/16 - 0s - 17ms/step - loss: 249.6519 - val_loss: 407.5559 - learning_rate: 4.4847e-04
# Epoch 92/200
# 16/16 - 0s - 16ms/step - loss: 236.4236 - val_loss: 409.0885 - learning_rate: 4.4847e-04
# Epoch 93/200
# 16/16 - 0s - 19ms/step - loss: 248.9719 - val_loss: 409.3586 - learning_rate: 4.4847e-04
# Epoch 94/200
# 16/16 - 0s - 17ms/step - loss: 257.8123 - val_loss: 407.1436 - learning_rate: 4.4847e-04
# Epoch 95/200
# 16/16 - 0s - 21ms/step - loss: 235.1014 - val_loss: 406.0880 - learning_rate: 4.4847e-04
# Epoch 96/200
# 16/16 - 0s - 17ms/step - loss: 232.4207 - val_loss: 406.0344 - learning_rate: 4.4847e-04
# Epoch 97/200
# 16/16 - 0s - 18ms/step - loss: 231.2848 - val_loss: 405.5643 - learning_rate: 4.4847e-04
# Epoch 98/200
# 16/16 - 0s - 18ms/step - loss: 229.8669 - val_loss: 405.1992 - learning_rate: 4.4847e-04
# Epoch 99/200
# 16/16 - 0s - 17ms/step - loss: 231.3636 - val_loss: 406.3069 - learning_rate: 4.4847e-04
# Epoch 100/200
# 16/16 - 0s - 16ms/step - loss: 217.9260 - val_loss: 404.0769 - learning_rate: 4.4847e-04
# Epoch 101/200
# 16/16 - 0s - 21ms/step - loss: 216.0241 - val_loss: 404.6717 - learning_rate: 4.4847e-04
# Epoch 102/200
# 16/16 - 0s - 22ms/step - loss: 232.0692 - val_loss: 407.3135 - learning_rate: 4.4847e-04
# Epoch 103/200
# 16/16 - 0s - 19ms/step - loss: 237.3605 - val_loss: 409.4433 - learning_rate: 4.4847e-04
# Epoch 104/200
# 16/16 - 0s - 18ms/step - loss: 215.1268 - val_loss: 409.2905 - learning_rate: 4.4847e-04
# Epoch 105/200
# 16/16 - 0s - 17ms/step - loss: 222.5141 - val_loss: 407.1130 - learning_rate: 4.4847e-04
# Epoch 106/200
# 16/16 - 0s - 19ms/step - loss: 224.3865 - val_loss: 408.4356 - learning_rate: 2.2423e-04
# Epoch 107/200
# 16/16 - 0s - 22ms/step - loss: 213.8083 - val_loss: 407.7884 - learning_rate: 2.2423e-04
# Epoch 108/200
# 16/16 - 0s - 17ms/step - loss: 219.5164 - val_loss: 409.7964 - learning_rate: 2.2423e-04
# Epoch 109/200
# 16/16 - 0s - 21ms/step - loss: 217.7068 - val_loss: 411.4110 - learning_rate: 2.2423e-04
# Epoch 110/200
# 16/16 - 0s - 20ms/step - loss: 212.1985 - val_loss: 411.7207 - learning_rate: 2.2423e-04
# Epoch 111/200
# 16/16 - 0s - 21ms/step - loss: 210.4593 - val_loss: 412.8481 - learning_rate: 1.1212e-04
# Epoch 112/200
# 16/16 - 0s - 21ms/step - loss: 214.9649 - val_loss: 413.5195 - learning_rate: 1.1212e-04
# Epoch 113/200
# 16/16 - 0s - 17ms/step - loss: 223.0719 - val_loss: 414.3383 - learning_rate: 1.1212e-04
# Epoch 114/200
# 16/16 - 0s - 19ms/step - loss: 220.3008 - val_loss: 414.3144 - learning_rate: 1.1212e-04
# Epoch 115/200
# 16/16 - 0s - 19ms/step - loss: 202.5936 - val_loss: 413.0740 - learning_rate: 1.1212e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 1/200
# 16/16 - 3s - 174ms/step - loss: 4149.9443 - val_loss: 4007.0752 - learning_rate: 4.4847e-04
# Epoch 2/200
# 16/16 - 0s - 24ms/step - loss: 4113.8916 - val_loss: 3988.7515 - learning_rate: 4.4847e-04
# Epoch 3/200
# 16/16 - 0s - 19ms/step - loss: 4071.8408 - val_loss: 3969.0530 - learning_rate: 4.4847e-04
# Epoch 4/200
# 16/16 - 0s - 23ms/step - loss: 4040.7568 - val_loss: 3947.7249 - learning_rate: 4.4847e-04
# Epoch 5/200
# 16/16 - 1s - 37ms/step - loss: 4004.3809 - val_loss: 3924.9382 - learning_rate: 4.4847e-04
# Epoch 6/200
# 16/16 - 0s - 19ms/step - loss: 3973.4238 - val_loss: 3899.1580 - learning_rate: 4.4847e-04
# Epoch 7/200
# 16/16 - 0s - 21ms/step - loss: 3940.1067 - val_loss: 3871.8257 - learning_rate: 4.4847e-04
# Epoch 8/200
# 16/16 - 0s - 18ms/step - loss: 3907.8315 - val_loss: 3842.6714 - learning_rate: 4.4847e-04
# Epoch 9/200
# 16/16 - 0s - 19ms/step - loss: 3870.9363 - val_loss: 3811.0696 - learning_rate: 4.4847e-04
# Epoch 10/200
# 16/16 - 0s - 20ms/step - loss: 3831.9402 - val_loss: 3775.9956 - learning_rate: 4.4847e-04
# Epoch 11/200
# 16/16 - 0s - 20ms/step - loss: 3794.7710 - val_loss: 3738.6501 - learning_rate: 4.4847e-04
# Epoch 12/200
# 16/16 - 0s - 20ms/step - loss: 3753.6040 - val_loss: 3698.1755 - learning_rate: 4.4847e-04
# Epoch 13/200
# 16/16 - 0s - 20ms/step - loss: 3733.6384 - val_loss: 3655.4421 - learning_rate: 4.4847e-04
# Epoch 14/200
# 16/16 - 0s - 18ms/step - loss: 3685.4973 - val_loss: 3613.5757 - learning_rate: 4.4847e-04
# Epoch 15/200
# 16/16 - 0s - 17ms/step - loss: 3644.9949 - val_loss: 3567.6560 - learning_rate: 4.4847e-04
# Epoch 16/200
# 16/16 - 0s - 17ms/step - loss: 3606.1255 - val_loss: 3516.4080 - learning_rate: 4.4847e-04
# Epoch 17/200
# 16/16 - 0s - 21ms/step - loss: 3557.2500 - val_loss: 3466.1692 - learning_rate: 4.4847e-04
# Epoch 18/200
# 16/16 - 0s - 21ms/step - loss: 3525.6770 - val_loss: 3414.7002 - learning_rate: 4.4847e-04
# Epoch 19/200
# 16/16 - 0s - 20ms/step - loss: 3473.7314 - val_loss: 3362.5610 - learning_rate: 4.4847e-04
# Epoch 20/200
# 16/16 - 0s - 22ms/step - loss: 3433.2288 - val_loss: 3308.5132 - learning_rate: 4.4847e-04
# Epoch 21/200
# 16/16 - 0s - 22ms/step - loss: 3377.3691 - val_loss: 3259.0437 - learning_rate: 4.4847e-04
# Epoch 22/200
# 16/16 - 0s - 25ms/step - loss: 3332.7393 - val_loss: 3210.7378 - learning_rate: 4.4847e-04
# Epoch 23/200
# 16/16 - 0s - 19ms/step - loss: 3283.6353 - val_loss: 3156.0537 - learning_rate: 4.4847e-04
# Epoch 24/200
# 16/16 - 0s - 19ms/step - loss: 3229.8457 - val_loss: 3109.7546 - learning_rate: 4.4847e-04
# Epoch 25/200
# 16/16 - 0s - 20ms/step - loss: 3179.3889 - val_loss: 3057.3008 - learning_rate: 4.4847e-04
# Epoch 26/200
# 16/16 - 0s - 19ms/step - loss: 3152.9473 - val_loss: 3005.4382 - learning_rate: 4.4847e-04
# Epoch 27/200
# 16/16 - 0s - 18ms/step - loss: 3076.2100 - val_loss: 2954.2634 - learning_rate: 4.4847e-04
# Epoch 28/200
# 16/16 - 0s - 21ms/step - loss: 3015.4089 - val_loss: 2893.2510 - learning_rate: 4.4847e-04
# Epoch 29/200
# 16/16 - 0s - 20ms/step - loss: 2949.6758 - val_loss: 2834.3938 - learning_rate: 4.4847e-04
# Epoch 30/200
# 16/16 - 0s - 22ms/step - loss: 2889.3774 - val_loss: 2775.8879 - learning_rate: 4.4847e-04
# Epoch 31/200
# 16/16 - 0s - 20ms/step - loss: 2838.3635 - val_loss: 2719.3230 - learning_rate: 4.4847e-04
# Epoch 32/200
# 16/16 - 0s - 21ms/step - loss: 2766.2979 - val_loss: 2658.9875 - learning_rate: 4.4847e-04
# Epoch 33/200
# 16/16 - 0s - 18ms/step - loss: 2713.9041 - val_loss: 2598.0229 - learning_rate: 4.4847e-04
# Epoch 34/200
# 16/16 - 0s - 19ms/step - loss: 2650.1768 - val_loss: 2536.7673 - learning_rate: 4.4847e-04
# Epoch 35/200
# 16/16 - 0s - 18ms/step - loss: 2573.7056 - val_loss: 2474.2480 - learning_rate: 4.4847e-04
# Epoch 36/200
# 16/16 - 0s - 19ms/step - loss: 2524.8882 - val_loss: 2406.6714 - learning_rate: 4.4847e-04
# Epoch 37/200
# 16/16 - 0s - 20ms/step - loss: 2432.2551 - val_loss: 2337.4216 - learning_rate: 4.4847e-04
# Epoch 38/200
# 16/16 - 0s - 19ms/step - loss: 2369.4612 - val_loss: 2266.2397 - learning_rate: 4.4847e-04
# Epoch 39/200
# 16/16 - 0s - 16ms/step - loss: 2284.3381 - val_loss: 2197.9436 - learning_rate: 4.4847e-04
# Epoch 40/200
# 16/16 - 0s - 24ms/step - loss: 2240.3467 - val_loss: 2134.2185 - learning_rate: 4.4847e-04
# Epoch 41/200
# 16/16 - 0s - 19ms/step - loss: 2158.3057 - val_loss: 2070.6226 - learning_rate: 4.4847e-04
# Epoch 42/200
# 16/16 - 0s - 19ms/step - loss: 2059.1909 - val_loss: 1996.0494 - learning_rate: 4.4847e-04
# Epoch 43/200
# 16/16 - 0s - 25ms/step - loss: 2004.8655 - val_loss: 1931.6090 - learning_rate: 4.4847e-04
# Epoch 44/200
# 16/16 - 1s - 39ms/step - loss: 1936.3737 - val_loss: 1855.8217 - learning_rate: 4.4847e-04
# Epoch 45/200
# 16/16 - 0s - 22ms/step - loss: 1875.9121 - val_loss: 1789.3612 - learning_rate: 4.4847e-04
# Epoch 46/200
# 16/16 - 0s - 17ms/step - loss: 1782.5376 - val_loss: 1719.6979 - learning_rate: 4.4847e-04
# Epoch 47/200
# 16/16 - 0s - 23ms/step - loss: 1713.0095 - val_loss: 1657.0137 - learning_rate: 4.4847e-04
# Epoch 48/200
# 16/16 - 0s - 22ms/step - loss: 1636.2269 - val_loss: 1594.9098 - learning_rate: 4.4847e-04
# Epoch 49/200
# 16/16 - 0s - 20ms/step - loss: 1585.2166 - val_loss: 1525.0928 - learning_rate: 4.4847e-04
# Epoch 50/200
# 16/16 - 0s - 16ms/step - loss: 1514.3577 - val_loss: 1461.5582 - learning_rate: 4.4847e-04
# Epoch 51/200
# 16/16 - 0s - 24ms/step - loss: 1434.4496 - val_loss: 1401.1079 - learning_rate: 4.4847e-04
# Epoch 52/200
# 16/16 - 1s - 37ms/step - loss: 1389.6025 - val_loss: 1339.2888 - learning_rate: 4.4847e-04
# Epoch 53/200
# 16/16 - 0s - 22ms/step - loss: 1315.1091 - val_loss: 1285.7717 - learning_rate: 4.4847e-04
# Epoch 54/200
# 16/16 - 0s - 22ms/step - loss: 1247.9500 - val_loss: 1227.8630 - learning_rate: 4.4847e-04
# Epoch 55/200
# 16/16 - 0s - 22ms/step - loss: 1173.0834 - val_loss: 1171.2008 - learning_rate: 4.4847e-04
# Epoch 56/200
# 16/16 - 0s - 22ms/step - loss: 1138.9675 - val_loss: 1122.1041 - learning_rate: 4.4847e-04
# Epoch 57/200
# 16/16 - 0s - 21ms/step - loss: 1078.2385 - val_loss: 1075.5557 - learning_rate: 4.4847e-04
# Epoch 58/200
# 16/16 - 0s - 17ms/step - loss: 1027.2473 - val_loss: 1030.0646 - learning_rate: 4.4847e-04
# Epoch 59/200
# 16/16 - 0s - 22ms/step - loss: 975.8707 - val_loss: 984.6849 - learning_rate: 4.4847e-04
# Epoch 60/200
# 16/16 - 0s - 19ms/step - loss: 894.8771 - val_loss: 936.1114 - learning_rate: 4.4847e-04
# Epoch 61/200
# 16/16 - 0s - 16ms/step - loss: 854.6341 - val_loss: 896.9391 - learning_rate: 4.4847e-04
# Epoch 62/200
# 16/16 - 0s - 21ms/step - loss: 829.3210 - val_loss: 858.2217 - learning_rate: 4.4847e-04
# Epoch 63/200
# 16/16 - 0s - 18ms/step - loss: 765.5545 - val_loss: 818.1192 - learning_rate: 4.4847e-04
# Epoch 64/200
# 16/16 - 0s - 21ms/step - loss: 747.3737 - val_loss: 783.6381 - learning_rate: 4.4847e-04
# Epoch 65/200
# 16/16 - 0s - 16ms/step - loss: 699.5587 - val_loss: 748.4084 - learning_rate: 4.4847e-04
# Epoch 66/200
# 16/16 - 0s - 21ms/step - loss: 666.4445 - val_loss: 711.2809 - learning_rate: 4.4847e-04
# Epoch 67/200
# 16/16 - 0s - 22ms/step - loss: 620.9385 - val_loss: 678.9436 - learning_rate: 4.4847e-04
# Epoch 68/200
# 16/16 - 0s - 20ms/step - loss: 585.8806 - val_loss: 652.4405 - learning_rate: 4.4847e-04
# Epoch 69/200
# 16/16 - 0s - 19ms/step - loss: 577.4458 - val_loss: 624.4204 - learning_rate: 4.4847e-04
# Epoch 70/200
# 16/16 - 0s - 22ms/step - loss: 533.3685 - val_loss: 602.5841 - learning_rate: 4.4847e-04
# Epoch 71/200
# 16/16 - 0s - 16ms/step - loss: 505.3775 - val_loss: 586.9359 - learning_rate: 4.4847e-04
# Epoch 72/200
# 16/16 - 0s - 22ms/step - loss: 454.6114 - val_loss: 561.7236 - learning_rate: 4.4847e-04
# Epoch 73/200
# 16/16 - 0s - 18ms/step - loss: 458.5786 - val_loss: 538.3246 - learning_rate: 4.4847e-04
# Epoch 74/200
# 16/16 - 0s - 22ms/step - loss: 416.9715 - val_loss: 514.4661 - learning_rate: 4.4847e-04
# Epoch 75/200
# 16/16 - 0s - 20ms/step - loss: 420.0116 - val_loss: 497.9511 - learning_rate: 4.4847e-04
# Epoch 76/200
# 16/16 - 0s - 18ms/step - loss: 379.0401 - val_loss: 482.7237 - learning_rate: 4.4847e-04
# Epoch 77/200
# 16/16 - 0s - 21ms/step - loss: 368.5892 - val_loss: 471.7549 - learning_rate: 4.4847e-04
# Epoch 78/200
# 16/16 - 0s - 21ms/step - loss: 352.1631 - val_loss: 461.2800 - learning_rate: 4.4847e-04
# Epoch 79/200
# 16/16 - 0s - 20ms/step - loss: 341.4284 - val_loss: 452.3890 - learning_rate: 4.4847e-04
# Epoch 80/200
# 16/16 - 0s - 21ms/step - loss: 311.7950 - val_loss: 440.1312 - learning_rate: 4.4847e-04
# Epoch 81/200
# 16/16 - 0s - 22ms/step - loss: 326.2311 - val_loss: 431.7635 - learning_rate: 4.4847e-04
# Epoch 82/200
# 16/16 - 0s - 19ms/step - loss: 317.6031 - val_loss: 420.2073 - learning_rate: 4.4847e-04
# Epoch 83/200
# 16/16 - 0s - 18ms/step - loss: 280.6053 - val_loss: 413.0587 - learning_rate: 4.4847e-04
# Epoch 84/200
# 16/16 - 0s - 24ms/step - loss: 282.3192 - val_loss: 409.6434 - learning_rate: 4.4847e-04
# Epoch 85/200
# 16/16 - 0s - 19ms/step - loss: 263.7409 - val_loss: 405.1336 - learning_rate: 4.4847e-04
# Epoch 86/200
# 16/16 - 0s - 17ms/step - loss: 270.1799 - val_loss: 399.1624 - learning_rate: 4.4847e-04
# Epoch 87/200
# 16/16 - 0s - 18ms/step - loss: 246.7750 - val_loss: 390.9294 - learning_rate: 4.4847e-04
# Epoch 88/200
# 16/16 - 0s - 23ms/step - loss: 245.2028 - val_loss: 384.9307 - learning_rate: 4.4847e-04
# Epoch 89/200
# 16/16 - 0s - 19ms/step - loss: 259.6728 - val_loss: 385.4695 - learning_rate: 4.4847e-04
# Epoch 90/200
# 16/16 - 0s - 19ms/step - loss: 238.3438 - val_loss: 384.4025 - learning_rate: 4.4847e-04
# Epoch 91/200
# 16/16 - 0s - 21ms/step - loss: 235.4110 - val_loss: 383.2837 - learning_rate: 4.4847e-04
# Epoch 92/200
# 16/16 - 0s - 17ms/step - loss: 241.0652 - val_loss: 383.2861 - learning_rate: 4.4847e-04
# Epoch 93/200
# 16/16 - 0s - 19ms/step - loss: 219.4357 - val_loss: 380.7227 - learning_rate: 4.4847e-04
# Epoch 94/200
# 16/16 - 0s - 20ms/step - loss: 231.8270 - val_loss: 379.8232 - learning_rate: 4.4847e-04
# Epoch 95/200
# 16/16 - 0s - 24ms/step - loss: 223.6181 - val_loss: 376.5562 - learning_rate: 4.4847e-04
# Epoch 96/200
# 16/16 - 0s - 18ms/step - loss: 220.0720 - val_loss: 375.9034 - learning_rate: 4.4847e-04
# Epoch 97/200
# 16/16 - 0s - 18ms/step - loss: 217.8726 - val_loss: 378.8016 - learning_rate: 4.4847e-04
# Epoch 98/200
# 16/16 - 0s - 20ms/step - loss: 210.0828 - val_loss: 378.5062 - learning_rate: 4.4847e-04
# Epoch 99/200
# 16/16 - 0s - 21ms/step - loss: 222.4456 - val_loss: 379.8536 - learning_rate: 4.4847e-04
# Epoch 100/200
# 16/16 - 0s - 21ms/step - loss: 211.7186 - val_loss: 379.8892 - learning_rate: 4.4847e-04
# Epoch 101/200
# 16/16 - 0s - 17ms/step - loss: 203.7153 - val_loss: 379.9397 - learning_rate: 4.4847e-04
# Epoch 102/200
# 16/16 - 0s - 20ms/step - loss: 215.9546 - val_loss: 379.2317 - learning_rate: 2.2423e-04
# Epoch 103/200
# 16/16 - 0s - 22ms/step - loss: 209.0304 - val_loss: 376.9023 - learning_rate: 2.2423e-04
# Epoch 104/200
# 16/16 - 0s - 20ms/step - loss: 214.5415 - val_loss: 376.8850 - learning_rate: 2.2423e-04
# Epoch 105/200
# 16/16 - 0s - 21ms/step - loss: 209.3576 - val_loss: 379.3087 - learning_rate: 2.2423e-04
# Epoch 106/200
# 16/16 - 0s - 19ms/step - loss: 198.3283 - val_loss: 380.1042 - learning_rate: 2.2423e-04
# Epoch 107/200
# 16/16 - 0s - 18ms/step - loss: 203.2228 - val_loss: 380.3025 - learning_rate: 1.1212e-04
# Epoch 108/200
# 16/16 - 0s - 20ms/step - loss: 211.5108 - val_loss: 380.5704 - learning_rate: 1.1212e-04
# Epoch 109/200
# 16/16 - 0s - 21ms/step - loss: 207.3586 - val_loss: 379.5018 - learning_rate: 1.1212e-04
# Epoch 110/200
# 16/16 - 0s - 21ms/step - loss: 207.2185 - val_loss: 379.3778 - learning_rate: 1.1212e-04
# Epoch 111/200
# 16/16 - 0s - 18ms/step - loss: 202.4819 - val_loss: 379.4201 - learning_rate: 1.1212e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Epoch 1/200
# 16/16 - 3s - 176ms/step - loss: 4165.7520 - val_loss: 4174.3145 - learning_rate: 4.4847e-04
# Epoch 2/200
# 16/16 - 0s - 20ms/step - loss: 4119.1343 - val_loss: 4150.2959 - learning_rate: 4.4847e-04
# Epoch 3/200
# 16/16 - 0s - 22ms/step - loss: 4080.9741 - val_loss: 4124.7329 - learning_rate: 4.4847e-04
# Epoch 4/200
# 16/16 - 1s - 41ms/step - loss: 4039.1826 - val_loss: 4098.5361 - learning_rate: 4.4847e-04
# Epoch 5/200
# 16/16 - 1s - 38ms/step - loss: 4002.6418 - val_loss: 4070.8298 - learning_rate: 4.4847e-04
# Epoch 6/200
# 16/16 - 0s - 20ms/step - loss: 3964.5059 - val_loss: 4041.6138 - learning_rate: 4.4847e-04
# Epoch 7/200
# 16/16 - 0s - 22ms/step - loss: 3926.4858 - val_loss: 4009.0713 - learning_rate: 4.4847e-04
# Epoch 8/200
# 16/16 - 0s - 21ms/step - loss: 3899.4722 - val_loss: 3974.9055 - learning_rate: 4.4847e-04
# Epoch 9/200
# 16/16 - 0s - 20ms/step - loss: 3859.8660 - val_loss: 3939.2292 - learning_rate: 4.4847e-04
# Epoch 10/200
# 16/16 - 0s - 21ms/step - loss: 3824.8613 - val_loss: 3899.6655 - learning_rate: 4.4847e-04
# Epoch 11/200
# 16/16 - 0s - 21ms/step - loss: 3797.7412 - val_loss: 3857.0835 - learning_rate: 4.4847e-04
# Epoch 12/200
# 16/16 - 0s - 16ms/step - loss: 3759.5425 - val_loss: 3812.5708 - learning_rate: 4.4847e-04
# Epoch 13/200
# 16/16 - 0s - 17ms/step - loss: 3714.7847 - val_loss: 3767.2117 - learning_rate: 4.4847e-04
# Epoch 14/200
# 16/16 - 0s - 22ms/step - loss: 3687.9587 - val_loss: 3720.8306 - learning_rate: 4.4847e-04
# Epoch 15/200
# 16/16 - 0s - 19ms/step - loss: 3633.2910 - val_loss: 3670.4758 - learning_rate: 4.4847e-04
# Epoch 16/200
# 16/16 - 0s - 19ms/step - loss: 3593.6321 - val_loss: 3619.5908 - learning_rate: 4.4847e-04
# Epoch 17/200
# 16/16 - 0s - 25ms/step - loss: 3560.7493 - val_loss: 3569.5806 - learning_rate: 4.4847e-04
# Epoch 18/200
# 16/16 - 0s - 17ms/step - loss: 3511.8318 - val_loss: 3515.7874 - learning_rate: 4.4847e-04
# Epoch 19/200
# 16/16 - 0s - 24ms/step - loss: 3474.1143 - val_loss: 3463.1646 - learning_rate: 4.4847e-04
# Epoch 20/200
# 16/16 - 1s - 41ms/step - loss: 3420.7310 - val_loss: 3411.2317 - learning_rate: 4.4847e-04
# Epoch 21/200
# 16/16 - 0s - 18ms/step - loss: 3369.3701 - val_loss: 3353.4382 - learning_rate: 4.4847e-04
# Epoch 22/200
# 16/16 - 0s - 21ms/step - loss: 3319.7168 - val_loss: 3302.8784 - learning_rate: 4.4847e-04
# Epoch 23/200
# 16/16 - 0s - 19ms/step - loss: 3293.1033 - val_loss: 3247.3855 - learning_rate: 4.4847e-04
# Epoch 24/200
# 16/16 - 0s - 23ms/step - loss: 3217.3167 - val_loss: 3192.4109 - learning_rate: 4.4847e-04
# Epoch 25/200
# 16/16 - 0s - 19ms/step - loss: 3167.5867 - val_loss: 3140.4470 - learning_rate: 4.4847e-04
# Epoch 26/200
# 16/16 - 0s - 19ms/step - loss: 3119.7981 - val_loss: 3086.8552 - learning_rate: 4.4847e-04
# Epoch 27/200
# 16/16 - 0s - 22ms/step - loss: 3085.9956 - val_loss: 3024.8933 - learning_rate: 4.4847e-04
# Epoch 28/200
# 16/16 - 0s - 19ms/step - loss: 3014.3069 - val_loss: 2964.2065 - learning_rate: 4.4847e-04
# Epoch 29/200
# 16/16 - 0s - 18ms/step - loss: 2947.6025 - val_loss: 2907.9900 - learning_rate: 4.4847e-04
# Epoch 30/200
# 16/16 - 0s - 18ms/step - loss: 2888.7756 - val_loss: 2848.8596 - learning_rate: 4.4847e-04
# Epoch 31/200
# 16/16 - 0s - 23ms/step - loss: 2823.4329 - val_loss: 2794.5154 - learning_rate: 4.4847e-04
# Epoch 32/200
# 16/16 - 0s - 20ms/step - loss: 2784.3848 - val_loss: 2735.9700 - learning_rate: 4.4847e-04
# Epoch 33/200
# 16/16 - 0s - 18ms/step - loss: 2686.8174 - val_loss: 2666.4253 - learning_rate: 4.4847e-04
# Epoch 34/200
# 16/16 - 0s - 22ms/step - loss: 2620.4897 - val_loss: 2601.5066 - learning_rate: 4.4847e-04
# Epoch 35/200
# 16/16 - 0s - 20ms/step - loss: 2565.0547 - val_loss: 2540.1899 - learning_rate: 4.4847e-04
# Epoch 36/200
# 16/16 - 0s - 20ms/step - loss: 2491.4573 - val_loss: 2476.8452 - learning_rate: 4.4847e-04
# Epoch 37/200
# 16/16 - 0s - 21ms/step - loss: 2426.6702 - val_loss: 2395.3281 - learning_rate: 4.4847e-04
# Epoch 38/200
# 16/16 - 0s - 19ms/step - loss: 2345.7893 - val_loss: 2323.9954 - learning_rate: 4.4847e-04
# Epoch 39/200
# 16/16 - 0s - 23ms/step - loss: 2278.4861 - val_loss: 2250.5889 - learning_rate: 4.4847e-04
# Epoch 40/200
# 16/16 - 1s - 42ms/step - loss: 2206.1260 - val_loss: 2172.8960 - learning_rate: 4.4847e-04
# Epoch 41/200
# 16/16 - 0s - 17ms/step - loss: 2141.2292 - val_loss: 2103.8396 - learning_rate: 4.4847e-04
# Epoch 42/200
# 16/16 - 0s - 22ms/step - loss: 2064.6262 - val_loss: 2042.2316 - learning_rate: 4.4847e-04
# Epoch 43/200
# 16/16 - 0s - 20ms/step - loss: 1977.8752 - val_loss: 1968.0396 - learning_rate: 4.4847e-04
# Epoch 44/200
# 16/16 - 0s - 21ms/step - loss: 1925.5479 - val_loss: 1899.1617 - learning_rate: 4.4847e-04
# Epoch 45/200
# 16/16 - 0s - 20ms/step - loss: 1845.9718 - val_loss: 1830.3527 - learning_rate: 4.4847e-04
# Epoch 46/200
# 16/16 - 0s - 23ms/step - loss: 1766.9977 - val_loss: 1762.4222 - learning_rate: 4.4847e-04
# Epoch 47/200
# 16/16 - 0s - 18ms/step - loss: 1731.0764 - val_loss: 1695.9413 - learning_rate: 4.4847e-04
# Epoch 48/200
# 16/16 - 0s - 18ms/step - loss: 1645.8986 - val_loss: 1623.4561 - learning_rate: 4.4847e-04
# Epoch 49/200
# 16/16 - 0s - 21ms/step - loss: 1558.6318 - val_loss: 1560.7053 - learning_rate: 4.4847e-04
# Epoch 50/200
# 16/16 - 0s - 21ms/step - loss: 1533.4017 - val_loss: 1497.3562 - learning_rate: 4.4847e-04
# Epoch 51/200
# 16/16 - 0s - 21ms/step - loss: 1462.5028 - val_loss: 1436.4323 - learning_rate: 4.4847e-04
# Epoch 52/200
# 16/16 - 0s - 20ms/step - loss: 1368.5507 - val_loss: 1381.1021 - learning_rate: 4.4847e-04
# Epoch 53/200
# 16/16 - 0s - 18ms/step - loss: 1308.2618 - val_loss: 1326.8728 - learning_rate: 4.4847e-04
# Epoch 54/200
# 16/16 - 0s - 19ms/step - loss: 1252.9644 - val_loss: 1263.3319 - learning_rate: 4.4847e-04
# Epoch 55/200
# 16/16 - 0s - 18ms/step - loss: 1191.8687 - val_loss: 1197.1028 - learning_rate: 4.4847e-04
# Epoch 56/200
# 16/16 - 0s - 20ms/step - loss: 1131.9127 - val_loss: 1147.2170 - learning_rate: 4.4847e-04
# Epoch 57/200
# 16/16 - 0s - 20ms/step - loss: 1094.5421 - val_loss: 1093.8632 - learning_rate: 4.4847e-04
# Epoch 58/200
# 16/16 - 0s - 19ms/step - loss: 1026.4911 - val_loss: 1047.7927 - learning_rate: 4.4847e-04
# Epoch 59/200
# 16/16 - 0s - 18ms/step - loss: 992.1193 - val_loss: 994.5660 - learning_rate: 4.4847e-04
# Epoch 60/200
# 16/16 - 0s - 20ms/step - loss: 916.0239 - val_loss: 951.9802 - learning_rate: 4.4847e-04
# Epoch 61/200
# 16/16 - 0s - 19ms/step - loss: 884.1943 - val_loss: 915.1919 - learning_rate: 4.4847e-04
# Epoch 62/200
# 16/16 - 0s - 19ms/step - loss: 823.5782 - val_loss: 874.0256 - learning_rate: 4.4847e-04
# Epoch 63/200
# 16/16 - 0s - 19ms/step - loss: 791.8033 - val_loss: 830.6267 - learning_rate: 4.4847e-04
# Epoch 64/200
# 16/16 - 0s - 20ms/step - loss: 729.5294 - val_loss: 790.6647 - learning_rate: 4.4847e-04
# Epoch 65/200
# 16/16 - 0s - 20ms/step - loss: 683.8478 - val_loss: 754.1065 - learning_rate: 4.4847e-04
# Epoch 66/200
# 16/16 - 0s - 19ms/step - loss: 669.8911 - val_loss: 723.2653 - learning_rate: 4.4847e-04
# Epoch 67/200
# 16/16 - 0s - 18ms/step - loss: 629.6334 - val_loss: 693.6957 - learning_rate: 4.4847e-04
# Epoch 68/200
# 16/16 - 0s - 19ms/step - loss: 596.3007 - val_loss: 665.0626 - learning_rate: 4.4847e-04
# Epoch 69/200
# 16/16 - 0s - 20ms/step - loss: 556.3491 - val_loss: 635.6136 - learning_rate: 4.4847e-04
# Epoch 70/200
# 16/16 - 0s - 19ms/step - loss: 533.8998 - val_loss: 611.5093 - learning_rate: 4.4847e-04
# Epoch 71/200
# 16/16 - 0s - 19ms/step - loss: 499.5623 - val_loss: 582.4395 - learning_rate: 4.4847e-04
# Epoch 72/200
# 16/16 - 0s - 19ms/step - loss: 495.6299 - val_loss: 564.2882 - learning_rate: 4.4847e-04
# Epoch 73/200
# 16/16 - 0s - 18ms/step - loss: 469.5634 - val_loss: 541.3480 - learning_rate: 4.4847e-04
# Epoch 74/200
# 16/16 - 0s - 23ms/step - loss: 426.5458 - val_loss: 519.4067 - learning_rate: 4.4847e-04
# Epoch 75/200
# 16/16 - 0s - 19ms/step - loss: 422.8239 - val_loss: 499.8181 - learning_rate: 4.4847e-04
# Epoch 76/200
# 16/16 - 0s - 19ms/step - loss: 388.6169 - val_loss: 489.4144 - learning_rate: 4.4847e-04
# Epoch 77/200
# 16/16 - 0s - 21ms/step - loss: 366.6688 - val_loss: 476.5661 - learning_rate: 4.4847e-04
# Epoch 78/200
# 16/16 - 0s - 19ms/step - loss: 355.3181 - val_loss: 463.2075 - learning_rate: 4.4847e-04
# Epoch 79/200
# 16/16 - 0s - 24ms/step - loss: 352.1664 - val_loss: 449.2470 - learning_rate: 4.4847e-04
# Epoch 80/200
# 16/16 - 0s - 19ms/step - loss: 337.7023 - val_loss: 441.5185 - learning_rate: 4.4847e-04
# Epoch 81/200
# 16/16 - 0s - 19ms/step - loss: 329.2485 - val_loss: 433.4434 - learning_rate: 4.4847e-04
# Epoch 82/200
# 16/16 - 0s - 18ms/step - loss: 313.8312 - val_loss: 429.9879 - learning_rate: 4.4847e-04
# Epoch 83/200
# 16/16 - 0s - 21ms/step - loss: 308.5592 - val_loss: 420.7265 - learning_rate: 4.4847e-04
# Epoch 84/200
# 16/16 - 0s - 19ms/step - loss: 304.7388 - val_loss: 416.0721 - learning_rate: 4.4847e-04
# Epoch 85/200
# 16/16 - 0s - 22ms/step - loss: 269.3346 - val_loss: 412.7070 - learning_rate: 4.4847e-04
# Epoch 86/200
# 16/16 - 0s - 21ms/step - loss: 272.3283 - val_loss: 405.9542 - learning_rate: 4.4847e-04
# Epoch 87/200
# 16/16 - 0s - 17ms/step - loss: 259.1712 - val_loss: 400.7159 - learning_rate: 4.4847e-04
# Epoch 88/200
# 16/16 - 0s - 20ms/step - loss: 261.9472 - val_loss: 397.7317 - learning_rate: 4.4847e-04
# Epoch 89/200
# 16/16 - 0s - 20ms/step - loss: 244.8283 - val_loss: 395.2797 - learning_rate: 4.4847e-04
# Epoch 90/200
# 16/16 - 0s - 16ms/step - loss: 238.7849 - val_loss: 397.0331 - learning_rate: 4.4847e-04
# Epoch 91/200
# 16/16 - 0s - 23ms/step - loss: 248.5360 - val_loss: 395.1054 - learning_rate: 4.4847e-04
# Epoch 92/200
# 16/16 - 0s - 18ms/step - loss: 239.1000 - val_loss: 391.3938 - learning_rate: 4.4847e-04
# Epoch 93/200
# 16/16 - 0s - 18ms/step - loss: 258.4632 - val_loss: 386.4047 - learning_rate: 4.4847e-04
# Epoch 94/200
# 16/16 - 0s - 17ms/step - loss: 231.6208 - val_loss: 383.0993 - learning_rate: 4.4847e-04
# Epoch 95/200
# 16/16 - 0s - 16ms/step - loss: 214.2120 - val_loss: 380.5222 - learning_rate: 4.4847e-04
# Epoch 96/200
# 16/16 - 0s - 22ms/step - loss: 225.9724 - val_loss: 379.8537 - learning_rate: 4.4847e-04
# Epoch 97/200
# 16/16 - 0s - 20ms/step - loss: 225.1476 - val_loss: 378.1342 - learning_rate: 4.4847e-04
# Epoch 98/200
# 16/16 - 0s - 22ms/step - loss: 215.7249 - val_loss: 378.3516 - learning_rate: 4.4847e-04
# Epoch 99/200
# 16/16 - 0s - 17ms/step - loss: 212.5235 - val_loss: 375.3017 - learning_rate: 4.4847e-04
# Epoch 100/200
# 16/16 - 0s - 16ms/step - loss: 219.4855 - val_loss: 373.7525 - learning_rate: 4.4847e-04
# Epoch 101/200
# 16/16 - 0s - 17ms/step - loss: 238.7833 - val_loss: 375.6070 - learning_rate: 4.4847e-04
# Epoch 102/200
# 16/16 - 0s - 20ms/step - loss: 219.4469 - val_loss: 376.6456 - learning_rate: 4.4847e-04
# Epoch 103/200
# 16/16 - 0s - 17ms/step - loss: 228.1139 - val_loss: 379.3978 - learning_rate: 4.4847e-04
# Epoch 104/200
# 16/16 - 0s - 17ms/step - loss: 214.7732 - val_loss: 380.0354 - learning_rate: 4.4847e-04
# Epoch 105/200
# 16/16 - 0s - 20ms/step - loss: 229.5722 - val_loss: 374.7334 - learning_rate: 4.4847e-04
# Epoch 106/200
# 16/16 - 0s - 17ms/step - loss: 206.3253 - val_loss: 376.0827 - learning_rate: 2.2423e-04
# Epoch 107/200
# 16/16 - 0s - 19ms/step - loss: 211.5882 - val_loss: 376.2427 - learning_rate: 2.2423e-04
# Epoch 108/200
# 16/16 - 0s - 23ms/step - loss: 218.3084 - val_loss: 378.0914 - learning_rate: 2.2423e-04
# Epoch 109/200
# 16/16 - 0s - 19ms/step - loss: 217.8328 - val_loss: 378.4002 - learning_rate: 2.2423e-04
# Epoch 110/200
# 16/16 - 0s - 17ms/step - loss: 226.6294 - val_loss: 378.4303 - learning_rate: 2.2423e-04
# Epoch 111/200
# 16/16 - 0s - 19ms/step - loss: 202.4703 - val_loss: 378.5150 - learning_rate: 1.1212e-04
# Epoch 112/200
# 16/16 - 0s - 17ms/step - loss: 213.3972 - val_loss: 378.5312 - learning_rate: 1.1212e-04
# Epoch 113/200
# 16/16 - 0s - 21ms/step - loss: 195.5099 - val_loss: 378.0774 - learning_rate: 1.1212e-04
# Epoch 114/200
# 16/16 - 0s - 19ms/step - loss: 201.6272 - val_loss: 379.0653 - learning_rate: 1.1212e-04
# Epoch 115/200
# 16/16 - 0s - 18ms/step - loss: 209.1529 - val_loss: 378.6099 - learning_rate: 1.1212e-04
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# The maximum residual is 80.9349 % embeddedness.
# The median residual is 12.554 % embeddedness.
# The minimum residual is 0.0445 % embeddedness.

# %% [markdown]
# ## Step 4. Model Comparison
# Based on the CV metrics, it appears that our models are not performing as well as hoped, but we are likely being held back by the data set. We will stop with the current model.

# %%
# Display dataframe with CV metrics
print(metric_df)
# Out:
#      CV RMSE     CV MAE     CV R2    CV NSE
# 0  18.100759  14.604296  0.426883  0.426883

# %% [markdown]
# Based on the above plots and CV metrics, we will move forward with the **GBR Model.**

# %% [markdown]
# ## Step 5. Export Model & Results

# %%
# Export metric dataframe (model comparison visualization)
metric_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "usepa_1819_metrics.xlsx")
metric_df.to_excel(metric_path)

# %%
# Save the trained model and train_test_split for later use
mdl_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "trained_gbr_model.pkl")
train_test_path = os.path.join(BASE_DIR, "usepa_nrsa", "results", "train_test_sets.pkl")

# Save sets/model
joblib.dump(gbr_model, mdl_path)
print('GBR model saved.')
joblib.dump((x_train_scld, x_test_scld, y_train, y_test), train_test_path)
print('Training and testing sets saved.')
